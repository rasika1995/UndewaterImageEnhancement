# %%
import imageio
import cv2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from matplotlib import pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dropout, BatchNormalization, Activation
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
K.clear_session()

def cnn_model(img, cb_img):
    
    conv_1 = Conv2D(16, (7, 7), activation='relu', padding='same', strides=1)(img)
    #batch_normed_1 = BatchNormalization()(conv_1)
    conv_2 = Conv2D(32, (5, 5), activation='relu', padding='same', strides=1)(conv_1)
    #batch_normed_2 = BatchNormalization()(conv_2)
    conv_3 = Conv2D(64, (3, 3), activation='relu', padding='same', strides=1)(conv_2)
    #batch_normed_3 = BatchNormalization()(conv_3)
    conv_4 = Conv2D(128, (3, 3), activation='relu', padding='same', strides=1)(conv_3)
    #batch_normed_4 = BatchNormalization()(conv_4)
   

    conv_5 = Conv2D(16, (7, 7), activation='relu', padding='same', strides=1)(cb_img)
    #batch_normed_5 = BatchNormalization()(conv_5)
    conv_6 = Conv2D(32, (5, 5), activation='relu', padding='same', strides=1)(conv_5)
    #batch_normed_6 = BatchNormalization()(conv_6)
    conv_7 = Conv2D(64, (3, 3), activation='relu', padding='same', strides=1)(conv_6)
    #batch_normed_7 = BatchNormalization()(conv_7)
    conv_8 = Conv2D(128, (3, 3), activation='relu', padding='same', strides=1)(conv_7)
    #batch_normed_8 = BatchNormalization()(conv_8)
   

    add_1 = tf.keras.layers.Add()([conv_4, conv_8])

    conv_9 = Conv2D(64, (7, 7), activation='relu', padding='same', strides=1)(add_1)
    #batch_normed_9 = BatchNormalization()(conv_9)
    conv_10 = Conv2D(32, (5, 5), activation='relu', padding='same', strides=1)(conv_9)
    #batch_normed_10 = BatchNormalization()(conv_10)

    dropout_1 = Dropout(0.2)(conv_10)
    conv_11 = Conv2D(16, (3, 3), activation='relu', padding='same', strides=1)(dropout_1)
    #batch_normed_11 = BatchNormalization()(conv_11)

    dropout_2 = Dropout(0.2)(conv_11)
    conv_12 = Conv2D(3, (3, 3), activation='relu', padding='same', strides=1)(dropout_1)

    # batch_normed_5 = BatchNormalization(momentum=0.99)(conv_5)
   

    #return batch_normed_5
    return conv_12

# %%
############################################################################################################# TRAINING PART ################################################################################################

# %%
d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/raw'
cb_d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/cb_raw'
t_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/reference'

data = []
cb_data = []
target = []

im_h = 224
im_w = 224
for imagePath in os.listdir(d_path):

    # get full the path of the raw(real), cb_raw(color balancing real) and reference(target) images
    data_path = os.path.join(d_path, imagePath)
    cb_data_path = os.path.join(cb_d_path, imagePath)
    target_path = os.path.join(t_path, imagePath)
    
    #read the images
    img = cv2.imread(data_path)
    cb_img = cv2.imread(cb_data_path)
    target_img = cv2.imread(target_path)

    #resize the images into 112 x 112
    img = cv2.resize(img, (im_h, im_w))
    cb_img = cv2.resize(cb_img, (im_h, im_w))
    target_img = cv2.resize(target_img, (im_h, im_w))
        
    # put the images into array list
    data.append(img)
    cb_data.append(cb_img)
    target.append(target_img)

# %%
# convert arrays into numpy arrays
data = np.array(data)
cb_data = np.array(cb_data)
target = np.array(target)

print(data.shape, cb_data.shape, target.shape)
# Out:
# (712, 224, 224, 3) (712, 224, 224, 3) (712, 224, 224, 3)

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7/'

# save the numpy arrays
np.save('data', data)
np.save('cb_data', cb_data)
np.save('target', target)
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7/'

# load the numpy arrays
data = np.load('data.npy')
cb_data = np.load('cb_data.npy')
target = np.load('target.npy')

print(data.shape, cb_data.shape, target.shape)
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7
# (712, 224, 224, 3) (712, 224, 224, 3) (712, 224, 224, 3)

# %%
im_h = 224
im_w = 224

# initiate keras tensor input_sample, input_cb_sample, and output_
input_sample = Input(shape=( im_h, im_w, 3))
input_cb_sample = Input(shape=( im_h,im_w, 3))
output_ = cnn_model(input_sample, input_cb_sample)

# create the model in function way by specfying input and output
model_enhancer = Model(inputs=[input_sample, input_cb_sample], outputs=output_)

# Configures the model for training with loss function and optimizer
model_enhancer.compile(loss='mse', optimizer='adam', metrics=['mse', 'accuracy'])
model_enhancer.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 224, 224, 16) 2368        input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 224, 224, 16) 2368        input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 224, 224, 32) 12832       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 224, 224, 32) 12832       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 224, 224, 64) 18496       conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 224, 224, 64) 18496       conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 224, 224, 128 73856       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 224, 224, 128 73856       conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 224, 224, 128 0           conv2d_15[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 224, 224, 64) 401472      add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 32) 51232       conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 224, 224, 32) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 224, 224, 3)  867         dropout_2[0][0]
# ==================================================================================================
# Total params: 668,675
# Trainable params: 668,675
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_enhancer, to_file='/content/drive/MyDrive/UnderwaterImageEnhancement/models/model7_view.png', show_shapes=True, show_layer_names=True)
Image(retina=True, filename='/content/drive/MyDrive/UnderwaterImageEnhancement/models/model7_view.png')

# %%
# split training dataset into 80% for training and 20% for validation
train_data, val_data, train_cb_data, val_cb_data, train_target, val_target = train_test_split(data,
                                                                                              cb_data,
                                                                                              target,
                                                                                              test_size=0.2)

print(len(train_data), len(train_cb_data), len(train_target), len(val_data), len(val_cb_data), len(val_target))
# Out:
# 569 569 569 143 143 143

# %%
epoch = 100

#
# checkpoint = ModelCheckpoint('/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/model-{epoch:03d}.h5', monitor="val_loss", save_best_only=False, mode='auto', save_freq=epoch)

# train the model
# history = model_enhancer.fit([train_data, train_cb_data], train_target, validation_data=([val_data, val_cb_data], val_target), batch_size=16, epochs=epoch, callbacks=[checkpoint], shuffle=True)

checkpoint_path = "/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss',mode='min', save_best_only=True, verbose=1)

# train the model
history = model_enhancer.fit([train_data, train_cb_data], train_target, validation_data=([val_data, val_cb_data], val_target), batch_size=16, epochs=epoch, callbacks=[cp_callback], shuffle=True)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 101s 2s/step - loss: 5625.1914 - mse: 5625.1929 - accuracy: 0.3559 - val_loss: 1730.3289 - val_mse: 1730.3289 - val_accuracy: 0.4427
#
# Epoch 00001: val_loss improved from inf to 1730.32886, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 36/36 [==============================] - 54s 1s/step - loss: 2011.2858 - mse: 2011.2860 - accuracy: 0.4798 - val_loss: 1162.5474 - val_mse: 1162.5471 - val_accuracy: 0.5990
#
# Epoch 00002: val_loss improved from 1730.32886 to 1162.54736, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 3/100
# 36/36 [==============================] - 54s 1s/step - loss: 1574.4989 - mse: 1574.4987 - accuracy: 0.5683 - val_loss: 1167.7200 - val_mse: 1167.7200 - val_accuracy: 0.5768
#
# Epoch 00003: val_loss did not improve from 1162.54736
# Epoch 4/100
# 36/36 [==============================] - 54s 1s/step - loss: 1571.9337 - mse: 1571.9337 - accuracy: 0.5737 - val_loss: 1160.2001 - val_mse: 1160.1998 - val_accuracy: 0.6365
#
# Epoch 00004: val_loss improved from 1162.54736 to 1160.20007, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 5/100
# 36/36 [==============================] - 54s 1s/step - loss: 1342.2686 - mse: 1342.2683 - accuracy: 0.5942 - val_loss: 927.0549 - val_mse: 927.0548 - val_accuracy: 0.6314
#
# Epoch 00005: val_loss improved from 1160.20007 to 927.05487, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 6/100
# 36/36 [==============================] - 54s 1s/step - loss: 1247.8174 - mse: 1247.8171 - accuracy: 0.6103 - val_loss: 885.7319 - val_mse: 885.7318 - val_accuracy: 0.6564
#
# Epoch 00006: val_loss improved from 927.05487 to 885.73187, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 7/100
# 36/36 [==============================] - 54s 1s/step - loss: 1179.3120 - mse: 1179.3119 - accuracy: 0.6194 - val_loss: 971.3665 - val_mse: 971.3666 - val_accuracy: 0.6561
#
# Epoch 00007: val_loss did not improve from 885.73187
# Epoch 8/100
# 36/36 [==============================] - 54s 1s/step - loss: 1171.3348 - mse: 1171.3347 - accuracy: 0.6265 - val_loss: 887.0175 - val_mse: 887.0175 - val_accuracy: 0.6713
#
# Epoch 00008: val_loss did not improve from 885.73187
# Epoch 9/100
# 36/36 [==============================] - 54s 1s/step - loss: 1110.3021 - mse: 1110.3021 - accuracy: 0.6320 - val_loss: 828.8629 - val_mse: 828.8629 - val_accuracy: 0.6480
#
# Epoch 00009: val_loss improved from 885.73187 to 828.86292, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 10/100
# 36/36 [==============================] - 54s 1s/step - loss: 1100.4265 - mse: 1100.4263 - accuracy: 0.6352 - val_loss: 1082.2628 - val_mse: 1082.2627 - val_accuracy: 0.6413
#
# Epoch 00010: val_loss did not improve from 828.86292
# Epoch 11/100
# 36/36 [==============================] - 54s 1s/step - loss: 1107.1190 - mse: 1107.1190 - accuracy: 0.6364 - val_loss: 968.2762 - val_mse: 968.2761 - val_accuracy: 0.6424
#
# Epoch 00011: val_loss did not improve from 828.86292
# Epoch 12/100
# 36/36 [==============================] - 54s 1s/step - loss: 1151.5811 - mse: 1151.5808 - accuracy: 0.6196 - val_loss: 946.0582 - val_mse: 946.0582 - val_accuracy: 0.6347
#
# Epoch 00012: val_loss did not improve from 828.86292
# Epoch 13/100
# 36/36 [==============================] - 54s 1s/step - loss: 1077.5302 - mse: 1077.5302 - accuracy: 0.6427 - val_loss: 843.2878 - val_mse: 843.2878 - val_accuracy: 0.6605
#
# Epoch 00013: val_loss did not improve from 828.86292
# Epoch 14/100
# 36/36 [==============================] - 54s 1s/step - loss: 1035.7086 - mse: 1035.7084 - accuracy: 0.6524 - val_loss: 789.1787 - val_mse: 789.1788 - val_accuracy: 0.6432
#
# Epoch 00014: val_loss improved from 828.86292 to 789.17871, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 15/100
# 36/36 [==============================] - 54s 1s/step - loss: 953.5978 - mse: 953.5978 - accuracy: 0.6525 - val_loss: 735.3510 - val_mse: 735.3510 - val_accuracy: 0.6852
#
# Epoch 00015: val_loss improved from 789.17871 to 735.35101, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 16/100
# 36/36 [==============================] - 54s 1s/step - loss: 1078.2617 - mse: 1078.2617 - accuracy: 0.6465 - val_loss: 940.4588 - val_mse: 940.4588 - val_accuracy: 0.5910
#
# Epoch 00016: val_loss did not improve from 735.35101
# Epoch 17/100
# 36/36 [==============================] - 54s 1s/step - loss: 995.0985 - mse: 995.0984 - accuracy: 0.6469 - val_loss: 810.3206 - val_mse: 810.3205 - val_accuracy: 0.6780
#
# Epoch 00017: val_loss did not improve from 735.35101
# Epoch 18/100
# 36/36 [==============================] - 54s 1s/step - loss: 1008.4188 - mse: 1008.4188 - accuracy: 0.6611 - val_loss: 940.4353 - val_mse: 940.4353 - val_accuracy: 0.6929
#
# Epoch 00018: val_loss did not improve from 735.35101
# Epoch 19/100
# 36/36 [==============================] - 54s 1s/step - loss: 1026.1311 - mse: 1026.1313 - accuracy: 0.6570 - val_loss: 859.1312 - val_mse: 859.1312 - val_accuracy: 0.6922
#
# Epoch 00019: val_loss did not improve from 735.35101
# Epoch 20/100
# 36/36 [==============================] - 54s 1s/step - loss: 1005.3216 - mse: 1005.3215 - accuracy: 0.6598 - val_loss: 796.1148 - val_mse: 796.1147 - val_accuracy: 0.6827
#
# Epoch 00020: val_loss did not improve from 735.35101
# Epoch 21/100
# 36/36 [==============================] - 54s 1s/step - loss: 922.1062 - mse: 922.1060 - accuracy: 0.6665 - val_loss: 816.0825 - val_mse: 816.0826 - val_accuracy: 0.6411
#
# Epoch 00021: val_loss did not improve from 735.35101
# Epoch 22/100
# 36/36 [==============================] - 54s 1s/step - loss: 907.7467 - mse: 907.7466 - accuracy: 0.6645 - val_loss: 1135.4308 - val_mse: 1135.4308 - val_accuracy: 0.6720
#
# Epoch 00022: val_loss did not improve from 735.35101
# Epoch 23/100
# 36/36 [==============================] - 54s 1s/step - loss: 943.5092 - mse: 943.5093 - accuracy: 0.6671 - val_loss: 699.2158 - val_mse: 699.2157 - val_accuracy: 0.6979
#
# Epoch 00023: val_loss improved from 735.35101 to 699.21576, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 24/100
# 36/36 [==============================] - 54s 1s/step - loss: 905.5542 - mse: 905.5542 - accuracy: 0.6700 - val_loss: 758.1240 - val_mse: 758.1240 - val_accuracy: 0.7020
#
# Epoch 00024: val_loss did not improve from 699.21576
# Epoch 25/100
# 36/36 [==============================] - 54s 1s/step - loss: 871.3870 - mse: 871.3870 - accuracy: 0.6627 - val_loss: 697.4962 - val_mse: 697.4962 - val_accuracy: 0.6946
#
# Epoch 00025: val_loss improved from 699.21576 to 697.49615, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 26/100
# 36/36 [==============================] - 54s 1s/step - loss: 902.8491 - mse: 902.8491 - accuracy: 0.6658 - val_loss: 1017.2866 - val_mse: 1017.2867 - val_accuracy: 0.6796
#
# Epoch 00026: val_loss did not improve from 697.49615
# Epoch 27/100
# 36/36 [==============================] - 54s 1s/step - loss: 1120.9863 - mse: 1120.9862 - accuracy: 0.6748 - val_loss: 906.4185 - val_mse: 906.4185 - val_accuracy: 0.6701
#
# Epoch 00027: val_loss did not improve from 697.49615
# Epoch 28/100
# 36/36 [==============================] - 54s 1s/step - loss: 977.7537 - mse: 977.7537 - accuracy: 0.6467 - val_loss: 823.8696 - val_mse: 823.8695 - val_accuracy: 0.6977
#
# Epoch 00028: val_loss did not improve from 697.49615
# Epoch 29/100
# 36/36 [==============================] - 54s 1s/step - loss: 897.1447 - mse: 897.1447 - accuracy: 0.6665 - val_loss: 668.4886 - val_mse: 668.4885 - val_accuracy: 0.7068
#
# Epoch 00029: val_loss improved from 697.49615 to 668.48859, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 30/100
# 36/36 [==============================] - 54s 1s/step - loss: 844.8068 - mse: 844.8066 - accuracy: 0.6762 - val_loss: 662.2352 - val_mse: 662.2351 - val_accuracy: 0.6910
#
# Epoch 00030: val_loss improved from 668.48859 to 662.23517, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 31/100
# 36/36 [==============================] - 54s 1s/step - loss: 856.9756 - mse: 856.9757 - accuracy: 0.6792 - val_loss: 711.7465 - val_mse: 711.7465 - val_accuracy: 0.7106
#
# Epoch 00031: val_loss did not improve from 662.23517
# Epoch 32/100
# 36/36 [==============================] - 54s 1s/step - loss: 837.9748 - mse: 837.9750 - accuracy: 0.6867 - val_loss: 693.5164 - val_mse: 693.5165 - val_accuracy: 0.6985
#
# Epoch 00032: val_loss did not improve from 662.23517
# Epoch 33/100
# 36/36 [==============================] - 54s 1s/step - loss: 847.4636 - mse: 847.4632 - accuracy: 0.6692 - val_loss: 694.2570 - val_mse: 694.2570 - val_accuracy: 0.6950
#
# Epoch 00033: val_loss did not improve from 662.23517
# Epoch 34/100
# 36/36 [==============================] - 54s 1s/step - loss: 862.7180 - mse: 862.7179 - accuracy: 0.6829 - val_loss: 843.8599 - val_mse: 843.8599 - val_accuracy: 0.6837
#
# Epoch 00034: val_loss did not improve from 662.23517
# Epoch 35/100
# 36/36 [==============================] - 54s 1s/step - loss: 952.8676 - mse: 952.8673 - accuracy: 0.6783 - val_loss: 653.5407 - val_mse: 653.5408 - val_accuracy: 0.6922
#
# Epoch 00035: val_loss improved from 662.23517 to 653.54071, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 36/100
# 36/36 [==============================] - 54s 1s/step - loss: 828.4987 - mse: 828.4988 - accuracy: 0.6913 - val_loss: 936.2623 - val_mse: 936.2623 - val_accuracy: 0.6838
#
# Epoch 00036: val_loss did not improve from 653.54071
# Epoch 37/100
# 36/36 [==============================] - 54s 1s/step - loss: 894.2672 - mse: 894.2672 - accuracy: 0.6797 - val_loss: 640.1556 - val_mse: 640.1556 - val_accuracy: 0.6878
#
# Epoch 00037: val_loss improved from 653.54071 to 640.15558, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 38/100
# 36/36 [==============================] - 54s 1s/step - loss: 844.7775 - mse: 844.7776 - accuracy: 0.6813 - val_loss: 723.9694 - val_mse: 723.9694 - val_accuracy: 0.6990
#
# Epoch 00038: val_loss did not improve from 640.15558
# Epoch 39/100
# 36/36 [==============================] - 54s 1s/step - loss: 835.3918 - mse: 835.3918 - accuracy: 0.6901 - val_loss: 649.4938 - val_mse: 649.4938 - val_accuracy: 0.7081
#
# Epoch 00039: val_loss did not improve from 640.15558
# Epoch 40/100
# 36/36 [==============================] - 54s 1s/step - loss: 846.0591 - mse: 846.0592 - accuracy: 0.6735 - val_loss: 636.2310 - val_mse: 636.2309 - val_accuracy: 0.6948
#
# Epoch 00040: val_loss improved from 640.15558 to 636.23102, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 41/100
# 36/36 [==============================] - 54s 1s/step - loss: 790.8933 - mse: 790.8932 - accuracy: 0.6929 - val_loss: 633.1354 - val_mse: 633.1354 - val_accuracy: 0.7127
#
# Epoch 00041: val_loss improved from 636.23102 to 633.13544, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 42/100
# 36/36 [==============================] - 54s 1s/step - loss: 788.8016 - mse: 788.8017 - accuracy: 0.6778 - val_loss: 712.5505 - val_mse: 712.5506 - val_accuracy: 0.6900
#
# Epoch 00042: val_loss did not improve from 633.13544
# Epoch 43/100
# 36/36 [==============================] - 54s 1s/step - loss: 799.8546 - mse: 799.8546 - accuracy: 0.6936 - val_loss: 668.7240 - val_mse: 668.7239 - val_accuracy: 0.6826
#
# Epoch 00043: val_loss did not improve from 633.13544
# Epoch 44/100
# 36/36 [==============================] - 54s 1s/step - loss: 867.2305 - mse: 867.2305 - accuracy: 0.6796 - val_loss: 653.8116 - val_mse: 653.8116 - val_accuracy: 0.7051
#
# Epoch 00044: val_loss did not improve from 633.13544
# Epoch 45/100
# 36/36 [==============================] - 54s 1s/step - loss: 840.6746 - mse: 840.6744 - accuracy: 0.6938 - val_loss: 785.8889 - val_mse: 785.8889 - val_accuracy: 0.6951
#
# Epoch 00045: val_loss did not improve from 633.13544
# Epoch 46/100
# 36/36 [==============================] - 54s 1s/step - loss: 772.3259 - mse: 772.3259 - accuracy: 0.6937 - val_loss: 649.2792 - val_mse: 649.2792 - val_accuracy: 0.6721
#
# Epoch 00046: val_loss did not improve from 633.13544
# Epoch 47/100
# 36/36 [==============================] - 54s 1s/step - loss: 799.4406 - mse: 799.4407 - accuracy: 0.6960 - val_loss: 702.7700 - val_mse: 702.7700 - val_accuracy: 0.7073
#
# Epoch 00047: val_loss did not improve from 633.13544
# Epoch 48/100
# 36/36 [==============================] - 54s 1s/step - loss: 765.1570 - mse: 765.1570 - accuracy: 0.6993 - val_loss: 617.8958 - val_mse: 617.8958 - val_accuracy: 0.7120
#
# Epoch 00048: val_loss improved from 633.13544 to 617.89581, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 49/100
# 36/36 [==============================] - 54s 1s/step - loss: 765.6842 - mse: 765.6843 - accuracy: 0.7014 - val_loss: 610.0117 - val_mse: 610.0117 - val_accuracy: 0.7137
#
# Epoch 00049: val_loss improved from 617.89581 to 610.01172, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 50/100
# 36/36 [==============================] - 54s 1s/step - loss: 837.2360 - mse: 837.2360 - accuracy: 0.6928 - val_loss: 619.1868 - val_mse: 619.1868 - val_accuracy: 0.7099
#
# Epoch 00050: val_loss did not improve from 610.01172
# Epoch 51/100
# 36/36 [==============================] - 54s 1s/step - loss: 770.8429 - mse: 770.8427 - accuracy: 0.7008 - val_loss: 619.9639 - val_mse: 619.9639 - val_accuracy: 0.7091
#
# Epoch 00051: val_loss did not improve from 610.01172
# Epoch 52/100
# 36/36 [==============================] - 54s 1s/step - loss: 710.4877 - mse: 710.4878 - accuracy: 0.7031 - val_loss: 594.7668 - val_mse: 594.7668 - val_accuracy: 0.7119
#
# Epoch 00052: val_loss improved from 610.01172 to 594.76678, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 53/100
# 36/36 [==============================] - 54s 1s/step - loss: 753.8817 - mse: 753.8816 - accuracy: 0.6961 - val_loss: 589.9692 - val_mse: 589.9692 - val_accuracy: 0.7181
#
# Epoch 00053: val_loss improved from 594.76678 to 589.96918, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 54/100
# 36/36 [==============================] - 54s 1s/step - loss: 723.7314 - mse: 723.7315 - accuracy: 0.7011 - val_loss: 918.7690 - val_mse: 918.7690 - val_accuracy: 0.7217
#
# Epoch 00054: val_loss did not improve from 589.96918
# Epoch 55/100
# 36/36 [==============================] - 54s 1s/step - loss: 804.3737 - mse: 804.3737 - accuracy: 0.7093 - val_loss: 648.5560 - val_mse: 648.5560 - val_accuracy: 0.7171
#
# Epoch 00055: val_loss did not improve from 589.96918
# Epoch 56/100
# 36/36 [==============================] - 54s 1s/step - loss: 746.3269 - mse: 746.3267 - accuracy: 0.7038 - val_loss: 576.6846 - val_mse: 576.6847 - val_accuracy: 0.7024
#
# Epoch 00056: val_loss improved from 589.96918 to 576.68463, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 57/100
# 36/36 [==============================] - 54s 1s/step - loss: 721.6106 - mse: 721.6105 - accuracy: 0.7020 - val_loss: 572.7245 - val_mse: 572.7246 - val_accuracy: 0.7226
#
# Epoch 00057: val_loss improved from 576.68463 to 572.72455, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 58/100
# 36/36 [==============================] - 54s 1s/step - loss: 705.6915 - mse: 705.6915 - accuracy: 0.7018 - val_loss: 598.5480 - val_mse: 598.5480 - val_accuracy: 0.7020
#
# Epoch 00058: val_loss did not improve from 572.72455
# Epoch 59/100
# 36/36 [==============================] - 54s 1s/step - loss: 703.1298 - mse: 703.1298 - accuracy: 0.7017 - val_loss: 728.4206 - val_mse: 728.4207 - val_accuracy: 0.6307
#
# Epoch 00059: val_loss did not improve from 572.72455
# Epoch 60/100
# 36/36 [==============================] - 54s 1s/step - loss: 760.7346 - mse: 760.7346 - accuracy: 0.6878 - val_loss: 595.0638 - val_mse: 595.0638 - val_accuracy: 0.6944
#
# Epoch 00060: val_loss did not improve from 572.72455
# Epoch 61/100
# 36/36 [==============================] - 54s 1s/step - loss: 767.2167 - mse: 767.2164 - accuracy: 0.7013 - val_loss: 657.6920 - val_mse: 657.6920 - val_accuracy: 0.7050
#
# Epoch 00061: val_loss did not improve from 572.72455
# Epoch 62/100
# 36/36 [==============================] - 54s 1s/step - loss: 735.3319 - mse: 735.3317 - accuracy: 0.6991 - val_loss: 662.2582 - val_mse: 662.2582 - val_accuracy: 0.6948
#
# Epoch 00062: val_loss did not improve from 572.72455
# Epoch 63/100
# 36/36 [==============================] - 54s 1s/step - loss: 714.7230 - mse: 714.7230 - accuracy: 0.7026 - val_loss: 664.2669 - val_mse: 664.2668 - val_accuracy: 0.7020
#
# Epoch 00063: val_loss did not improve from 572.72455
# Epoch 64/100
# 36/36 [==============================] - 54s 1s/step - loss: 757.9050 - mse: 757.9050 - accuracy: 0.7117 - val_loss: 645.2467 - val_mse: 645.2467 - val_accuracy: 0.7189
#
# Epoch 00064: val_loss did not improve from 572.72455
# Epoch 65/100
# 36/36 [==============================] - 54s 1s/step - loss: 819.6243 - mse: 819.6243 - accuracy: 0.7188 - val_loss: 813.3080 - val_mse: 813.3080 - val_accuracy: 0.6862
#
# Epoch 00065: val_loss did not improve from 572.72455
# Epoch 66/100
# 36/36 [==============================] - 54s 1s/step - loss: 775.3722 - mse: 775.3723 - accuracy: 0.6978 - val_loss: 729.3179 - val_mse: 729.3178 - val_accuracy: 0.6294
#
# Epoch 00066: val_loss did not improve from 572.72455
# Epoch 67/100
# 36/36 [==============================] - 54s 1s/step - loss: 806.7278 - mse: 806.7277 - accuracy: 0.6829 - val_loss: 641.1902 - val_mse: 641.1902 - val_accuracy: 0.6918
#
# Epoch 00067: val_loss did not improve from 572.72455
# Epoch 68/100
# 36/36 [==============================] - 54s 1s/step - loss: 762.8839 - mse: 762.8839 - accuracy: 0.6989 - val_loss: 594.2971 - val_mse: 594.2972 - val_accuracy: 0.6999
#
# Epoch 00068: val_loss did not improve from 572.72455
# Epoch 69/100
# 36/36 [==============================] - 54s 1s/step - loss: 891.4531 - mse: 891.4529 - accuracy: 0.6914 - val_loss: 631.0421 - val_mse: 631.0421 - val_accuracy: 0.7054
#
# Epoch 00069: val_loss did not improve from 572.72455
# Epoch 70/100
# 36/36 [==============================] - 54s 1s/step - loss: 752.7946 - mse: 752.7948 - accuracy: 0.6992 - val_loss: 723.1479 - val_mse: 723.1479 - val_accuracy: 0.6185
#
# Epoch 00070: val_loss did not improve from 572.72455
# Epoch 71/100
# 36/36 [==============================] - 54s 1s/step - loss: 728.7654 - mse: 728.7654 - accuracy: 0.7020 - val_loss: 573.9194 - val_mse: 573.9194 - val_accuracy: 0.7123
#
# Epoch 00071: val_loss did not improve from 572.72455
# Epoch 72/100
# 36/36 [==============================] - 54s 1s/step - loss: 734.9443 - mse: 734.9443 - accuracy: 0.7111 - val_loss: 587.0546 - val_mse: 587.0547 - val_accuracy: 0.7045
#
# Epoch 00072: val_loss did not improve from 572.72455
# Epoch 73/100
# 36/36 [==============================] - 54s 1s/step - loss: 772.3524 - mse: 772.3523 - accuracy: 0.6862 - val_loss: 636.1259 - val_mse: 636.1259 - val_accuracy: 0.7011
#
# Epoch 00073: val_loss did not improve from 572.72455
# Epoch 74/100
# 36/36 [==============================] - 54s 1s/step - loss: 749.2972 - mse: 749.2972 - accuracy: 0.7111 - val_loss: 633.1013 - val_mse: 633.1013 - val_accuracy: 0.7115
#
# Epoch 00074: val_loss did not improve from 572.72455
# Epoch 75/100
# 36/36 [==============================] - 54s 1s/step - loss: 714.4786 - mse: 714.4785 - accuracy: 0.7120 - val_loss: 744.8370 - val_mse: 744.8370 - val_accuracy: 0.6972
#
# Epoch 00075: val_loss did not improve from 572.72455
# Epoch 76/100
# 36/36 [==============================] - 54s 1s/step - loss: 743.0148 - mse: 743.0150 - accuracy: 0.7116 - val_loss: 677.5654 - val_mse: 677.5654 - val_accuracy: 0.7213
#
# Epoch 00076: val_loss did not improve from 572.72455
# Epoch 77/100
# 36/36 [==============================] - 54s 1s/step - loss: 761.2055 - mse: 761.2054 - accuracy: 0.7205 - val_loss: 562.5596 - val_mse: 562.5597 - val_accuracy: 0.6875
#
# Epoch 00077: val_loss improved from 572.72455 to 562.55963, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 78/100
# 36/36 [==============================] - 54s 1s/step - loss: 681.3434 - mse: 681.3433 - accuracy: 0.7128 - val_loss: 874.1248 - val_mse: 874.1249 - val_accuracy: 0.7010
#
# Epoch 00078: val_loss did not improve from 562.55963
# Epoch 79/100
# 36/36 [==============================] - 54s 1s/step - loss: 839.2723 - mse: 839.2724 - accuracy: 0.6901 - val_loss: 821.6445 - val_mse: 821.6445 - val_accuracy: 0.7056
#
# Epoch 00079: val_loss did not improve from 562.55963
# Epoch 80/100
# 36/36 [==============================] - 54s 1s/step - loss: 777.3623 - mse: 777.3623 - accuracy: 0.7016 - val_loss: 703.3143 - val_mse: 703.3144 - val_accuracy: 0.6348
#
# Epoch 00080: val_loss did not improve from 562.55963
# Epoch 81/100
# 36/36 [==============================] - 54s 1s/step - loss: 730.5201 - mse: 730.5201 - accuracy: 0.6975 - val_loss: 652.4203 - val_mse: 652.4203 - val_accuracy: 0.7020
#
# Epoch 00081: val_loss did not improve from 562.55963
# Epoch 82/100
# 36/36 [==============================] - 54s 1s/step - loss: 685.3038 - mse: 685.3038 - accuracy: 0.7114 - val_loss: 562.6276 - val_mse: 562.6276 - val_accuracy: 0.7170
#
# Epoch 00082: val_loss did not improve from 562.55963
# Epoch 83/100
# 36/36 [==============================] - 54s 1s/step - loss: 696.0295 - mse: 696.0294 - accuracy: 0.7185 - val_loss: 651.4473 - val_mse: 651.4474 - val_accuracy: 0.7034
#
# Epoch 00083: val_loss did not improve from 562.55963
# Epoch 84/100
# 36/36 [==============================] - 54s 1s/step - loss: 675.5844 - mse: 675.5844 - accuracy: 0.7134 - val_loss: 562.5409 - val_mse: 562.5409 - val_accuracy: 0.7061
#
# Epoch 00084: val_loss improved from 562.55963 to 562.54089, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 85/100
# 36/36 [==============================] - 54s 1s/step - loss: 706.1588 - mse: 706.1589 - accuracy: 0.7118 - val_loss: 787.4146 - val_mse: 787.4146 - val_accuracy: 0.6376
#
# Epoch 00085: val_loss did not improve from 562.54089
# Epoch 86/100
# 36/36 [==============================] - 54s 1s/step - loss: 773.9169 - mse: 773.9169 - accuracy: 0.7165 - val_loss: 594.0834 - val_mse: 594.0834 - val_accuracy: 0.7014
#
# Epoch 00086: val_loss did not improve from 562.54089
# Epoch 87/100
# 36/36 [==============================] - 54s 1s/step - loss: 690.1220 - mse: 690.1221 - accuracy: 0.7260 - val_loss: 643.5435 - val_mse: 643.5435 - val_accuracy: 0.6931
#
# Epoch 00087: val_loss did not improve from 562.54089
# Epoch 88/100
# 36/36 [==============================] - 54s 1s/step - loss: 721.3514 - mse: 721.3513 - accuracy: 0.7132 - val_loss: 668.6008 - val_mse: 668.6008 - val_accuracy: 0.7154
#
# Epoch 00088: val_loss did not improve from 562.54089
# Epoch 89/100
# 36/36 [==============================] - 54s 1s/step - loss: 720.5139 - mse: 720.5139 - accuracy: 0.7162 - val_loss: 563.1945 - val_mse: 563.1946 - val_accuracy: 0.7170
#
# Epoch 00089: val_loss did not improve from 562.54089
# Epoch 90/100
# 36/36 [==============================] - 54s 1s/step - loss: 674.1135 - mse: 674.1136 - accuracy: 0.7205 - val_loss: 571.8821 - val_mse: 571.8821 - val_accuracy: 0.7263
#
# Epoch 00090: val_loss did not improve from 562.54089
# Epoch 91/100
# 36/36 [==============================] - 54s 1s/step - loss: 749.4263 - mse: 749.4264 - accuracy: 0.7007 - val_loss: 620.3184 - val_mse: 620.3183 - val_accuracy: 0.7048
#
# Epoch 00091: val_loss did not improve from 562.54089
# Epoch 92/100
# 36/36 [==============================] - 54s 1s/step - loss: 693.2357 - mse: 693.2358 - accuracy: 0.7127 - val_loss: 547.6190 - val_mse: 547.6190 - val_accuracy: 0.7252
#
# Epoch 00092: val_loss improved from 562.54089 to 547.61902, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5
# Epoch 93/100
# 36/36 [==============================] - 54s 1s/step - loss: 681.6898 - mse: 681.6897 - accuracy: 0.7159 - val_loss: 708.7300 - val_mse: 708.7300 - val_accuracy: 0.7059
#
# Epoch 00093: val_loss did not improve from 547.61902
# Epoch 94/100
# 36/36 [==============================] - 54s 1s/step - loss: 696.4202 - mse: 696.4203 - accuracy: 0.7100 - val_loss: 685.1559 - val_mse: 685.1559 - val_accuracy: 0.7191
#
# Epoch 00094: val_loss did not improve from 547.61902
# Epoch 95/100
# 36/36 [==============================] - 54s 1s/step - loss: 694.1406 - mse: 694.1407 - accuracy: 0.7037 - val_loss: 837.9089 - val_mse: 837.9088 - val_accuracy: 0.7027
#
# Epoch 00095: val_loss did not improve from 547.61902
# Epoch 96/100
# 36/36 [==============================] - 54s 1s/step - loss: 734.7881 - mse: 734.7881 - accuracy: 0.6971 - val_loss: 609.0416 - val_mse: 609.0416 - val_accuracy: 0.6781
#
# Epoch 00096: val_loss did not improve from 547.61902
# Epoch 97/100
# 36/36 [==============================] - 54s 1s/step - loss: 683.1944 - mse: 683.1943 - accuracy: 0.7110 - val_loss: 710.2924 - val_mse: 710.2924 - val_accuracy: 0.7219
#
# Epoch 00097: val_loss did not improve from 547.61902
# Epoch 98/100
# 36/36 [==============================] - 54s 1s/step - loss: 656.0309 - mse: 656.0309 - accuracy: 0.7175 - val_loss: 583.6315 - val_mse: 583.6316 - val_accuracy: 0.6959
#
# Epoch 00098: val_loss did not improve from 547.61902
# Epoch 99/100
# 36/36 [==============================] - 54s 1s/step - loss: 723.8179 - mse: 723.8178 - accuracy: 0.7112 - val_loss: 723.8930 - val_mse: 723.8929 - val_accuracy: 0.7109
#
# Epoch 00099: val_loss did not improve from 547.61902
# Epoch 100/100
# 36/36 [==============================] - 54s 1s/step - loss: 658.5333 - mse: 658.5332 - accuracy: 0.7218 - val_loss: 663.9259 - val_mse: 663.9259 - val_accuracy: 0.7185
#
# Epoch 00100: val_loss did not improve from 547.61902

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'accuracy', 'val_loss', 'val_mse', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='validation')
plt.legend()
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
###################################################################################################### TESTING PART ####################################################################################################

# %%
###### How to load and use weights from a checkpoint #########

im_h = 224
im_w = 224

# initiate keras tensor input_sample, input_cb_sample, and output_
input_sample = Input(shape=(im_h, im_w, 3))
input_cb_sample = Input(shape=(im_h, im_w, 3))
output_ = cnn_model(input_sample, input_cb_sample)

# create the model in function way by specfying input and output
model_enhancer_test = Model(inputs=[input_sample, input_cb_sample], outputs=output_)

# load weights
model_enhancer_test.load_weights("/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model7/weights_best.hdf5")

# Configures the model for training with loss function and optimizer
model_enhancer_test.compile(loss='mse', optimizer='adam', metrics=['mse', 'accuracy'])

# %%
############################################################# Evaluate the model in testing part

d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/raw'
cb_d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/cb_raw'
t_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'

data = []
cb_data = []
target = []

im_h = 224
im_w = 224
for imagePath in os.listdir(d_path):

    # get full the path of the raw(real), cb_raw(color balancing real) and reference(target) images
    data_path = os.path.join(d_path, imagePath)
    cb_data_path = os.path.join(cb_d_path, imagePath)
    target_path = os.path.join(t_path, imagePath)
    
    #read the images
    img = cv2.imread(data_path)
    cb_img = cv2.imread(cb_data_path)
    target_img = cv2.imread(target_path)

    #resize the images 
    img = cv2.resize(img, (im_h, im_w))
    cb_img = cv2.resize(cb_img, (im_h, im_w))
    target_img = cv2.resize(target_img, (im_h, im_w))
        
    # put the images into array list
    data.append(img)
    cb_data.append(cb_img)
    target.append(target_img)


# convert arrays into numpy arrays
test_data = np.array(data)
test_cb_data = np.array(cb_data)
test_target = np.array(target)

print(test_data.shape, test_cb_data.shape, test_target.shape)

# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7/'

# save the numpy arrays
np.save('test_data', test_data)
np.save('test_cb_data', test_cb_data)
np.save('test_target', test_target)
# Out:
# (178, 224, 224, 3) (178, 224, 224, 3) (178, 224, 224, 3)
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7/'

# load the numpy arrays
test_data = np.load('test_data.npy')
test_cb_data = np.load('test_cb_data.npy')
test_target = np.load('test_target.npy')

print(test_data.shape, test_cb_data.shape, test_target.shape)


# estimate accuracy and the MSE on test dataset using loaded weights
scores = model_enhancer_test.evaluate([test_data, test_cb_data ], test_target, verbose=0)

#print("%s: %.2f%%" % (model_enhancer_test.metrics_names[2], scores[2]*100))
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7
# (178, 224, 224, 3) (178, 224, 224, 3) (178, 224, 224, 3)

# %%
# Testing Accuracy
print("%s: %.2f%%" % (model_enhancer_test.metrics_names[2], scores[2]*100))
# Out:
# accuracy: 70.99%

# %%
# Testing Loss - MSE for test data set
print(scores[1])
print('MSE for testing set: ', format(scores[1], ".4f"))
# Out:
# 521.0625610351562
# MSE for testing set:  521.0626

# %%
# PSNR for test data set

from math import log10, sqrt

def PSNR():
 mse = scores[1]
 #print(mse)
 if(mse == 0):
  return 100
 max_pixel = 255.0
 psnr = 20 * log10(max_pixel / sqrt(mse))
 return psnr 

value = PSNR()
print(value)

print('PSNR for testing set: ', format(value, ".4f"), "dB")
# Out:
# 20.961904911553027
# PSNR for testing set:  20.9619 dB

# %%
############################################################## predict the data using loaded weights

import numpy as np
from PIL import Image
import cv2
import os
from matplotlib import pyplot as plt


test_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/raw/'
cb_test_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/cb_raw'
destination = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model7-output/'

im_h = 224
im_w = 224
for test_img_name in os.listdir(test_path):

    #read the raw images
    test_img = cv2.imread(os.path.join(test_path, test_img_name))
    cb_test_img = cv2.imread(os.path.join(cb_test_path, test_img_name))
   
    #resize the images into 112 x 112
    test_img = cv2.resize(test_img, (im_h, im_w))
    cb_test_img = cv2.resize(cb_test_img, (im_h, im_w))
    
    # reshape the image (112, 112, 3) into (1, 112, 112, 3)
    test_img = test_img.reshape(1,im_h, im_w,3)
    cb_test_img = cb_test_img.reshape(1,im_h, im_w,3)

    # use model to do prediction
    #result = model_enhancer.predict([test_img, cb_test_img])
    result = model_enhancer_test.predict([test_img, cb_test_img])
    
    #
    result = result.squeeze()
    
    test_img = test_img.squeeze()
    
    test_img[:,:,:] = result[:,:,:]
    #plt.imshow(test_img)
    cv2.imwrite(os.path.join(destination, test_img_name), test_img)

# %%
"""


import numpy as np
import cv2
import os

from sklearn.metrics import mean_squared_error

target_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'
predicted_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model7-output/'

target_data = []
predict_data = []


im_h = 224
im_w = 224
for image_name in os.listdir(target_path):

    #read the raw images
    target_img = cv2.imread(os.path.join(target_path, image_name))
    predicted_img = cv2.imread(os.path.join(predicted_path, image_name))
    

    #resize the images into 112 x 112
    target_img = cv2.resize(target_img, (im_h, im_w))
    predicted_img = cv2.resize(predicted_img, (im_h, im_w))
        
    # put the images into array list
    target_data.append(target_img)
    predict_data.append(predicted_img)


# convert arrays into numpy arrays
target_data = np.array(target_data)
predict_data = np.array(predict_data)

print(target_data.shape, predict_data.shape)


# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7/'

# save the numpy arrays
np.save('target_data', target_data)
np.save('predict_data', predict_data)


"""

# %%
"""

# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model7/'

# load the numpy arrays
target_data = np.load('target_data.npy')
predict_data = np.load('predict_data.npy')

print(target_data.shape, predict_data.shape)

"""

# %%
"""


###### FULL-REFERENCE IMAGE QUALITY ASSESSMENT IN TERMS OF MSE, PSNR, AND SSIM #######

import numpy as np
  
# Mean Squared Error
MSE = np.square(np.subtract(target_data,predict_data)).mean()
print("MSE for test data :",MSE)


"""

# %%
"""


mse = (np.square(target_data - predict_data)).mean(axis=None)

print("MSE for test data :",mse)


"""

# %%
"""


# PSNR 

from math import log10, sqrt

def PSNR(target_data, predict_data):
 mse = np.mean((target_data - predict_data) ** 2)
 #print(mse)
 if(mse == 0):
  return 100
 max_pixel = 255.0
 psnr = 20 * log10(max_pixel / sqrt(mse))
 return psnr 


value = PSNR(target_data, predict_data)
print("\nPeak Signal-to-Noise Ratio (PSNR) value is", value, "dB")

"""

# %%
"""


#SSIM

from skimage.metrics import structural_similarity as ssim

ssim_value = ssim(target_data, predict_data, multichannel=True)
print("SSIM:", ssim_value)


"""

# %%
"""


from skimage.measure import compare_ssim

(score, diff) = compare_ssim(target_data, predict_data, full=True, multichannel=True)
diff = (diff * 255).astype("uint8")
print("SSIM:", score)

"""

# %%
###### FULL-REFERENCE IMAGE QUALITY ASSESSMENT IN TERMS OF MSE, PSNR, AND SSIM #######

import numpy as np
import cv2
import os

from skimage.metrics import mean_squared_error
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity 


target_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'
predicted_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model7-output/'


im_h = 224
im_w = 224

sumMSE = 0;
sumPSNR = 0;
sumSSIM = 0;
count = 0;


for image_name in os.listdir(target_path):

    #read the raw images
    target_img = cv2.imread(os.path.join(target_path, image_name))
    predicted_img = cv2.imread(os.path.join(predicted_path, image_name))
    

    #resize the images into 224 x 224
    target_img = cv2.resize(target_img, (im_h, im_w))
    predicted_img = cv2.resize(predicted_img, (im_h, im_w))


    #calculate the MSE, PSNR, and SSIM 
    MSE = mean_squared_error(target_img, predicted_img)
    PSNR = peak_signal_noise_ratio(target_img, predicted_img)
    SSIM = structural_similarity(target_img, predicted_img, multichannel=True)

    sumMSE = sumMSE + MSE
    sumPSNR = sumPSNR + PSNR
    sumSSIM = sumSSIM + SSIM
    count = count + 1
    
    # print('SSIM: ', SSIM)
    # print('MSE: ', MSE)
    # print('PSNR: ', PSNR)


# print('sumMSE: ',sumMSE)
# print('sumPSNR: ', sumPSNR)
# print('sumSSIM: ', sumSSIM)
# print('count: ', count)


# Get the Average value 
mse_value = sumMSE/count
psnr_value = sumPSNR/count
ssim_value = sumSSIM/count


print("MSE for testing data :", format(mse_value, ".4f"))
print("PSNR for testing data :", format(psnr_value, ".4f"), "dB")
print("SSIM for testing data :", format(ssim_value, ".4f"))
# Out:
# MSE for testing data : 661.5976
# PSNR for testing data : 20.9480 dB
# SSIM for testing data : 0.8593
