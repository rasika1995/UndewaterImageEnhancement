# %%
import imageio
import cv2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from matplotlib import pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
K.clear_session()

def cnn_model(img, cb_img):
    
    conv_1 = Conv2D(16, (7, 7), activation='relu', padding='same', strides=1)(img)
    batch_normed_1 = BatchNormalization()(conv_1)
    conv_1 = Conv2D(32, (5, 5), activation='relu', padding='same', strides=1)(batch_normed_1)
    batch_normed_1 = BatchNormalization()(conv_1)
    conv_1 = Conv2D(64, (3, 3), activation='relu', padding='same', strides=1)(batch_normed_1)
    batch_normed_1 = BatchNormalization()(conv_1)
   

    conv_2 = Conv2D(16, (7, 7), activation='relu', padding='same', strides=1)(cb_img)
    batch_normed_2 = BatchNormalization()(conv_2)
    conv_2 = Conv2D(32, (5, 5), activation='relu', padding='same', strides=1)(batch_normed_2)
    batch_normed_2 = BatchNormalization()(conv_2)
    conv_2 = Conv2D(64, (3, 3), activation='relu', padding='same', strides=1)(batch_normed_2)
    batch_normed_2 = BatchNormalization()(conv_2)
   

    add_1 = tf.keras.layers.Add()([batch_normed_1, batch_normed_2])

    conv_3 = Conv2D(16, (3, 3), activation='relu', padding='same', strides=1)(add_1)
    batch_normed_3 = BatchNormalization()(conv_3)
    conv_4 = Conv2D(16, (3, 3), activation='relu', padding='same', strides=1)(batch_normed_3)
    batch_normed_4 = BatchNormalization()(conv_4)

    conv_5 = Conv2D(3, (3, 3), activation='relu', padding='same', strides=1)(batch_normed_4)
    # batch_normed_5 = BatchNormalization()(conv_5)
   

    #return batch_normed_5
    return conv_5

# %%
############################################################################################################# TRAINING PART ################################################################################################

# %%
d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/raw'
cb_d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/cb_raw'
t_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/reference'

data = []
cb_data = []
target = []

im_h = 224
im_w = 224
for imagePath in os.listdir(d_path):

    # get full the path of the raw(real), cb_raw(color balancing real) and reference(target) images
    data_path = os.path.join(d_path, imagePath)
    cb_data_path = os.path.join(cb_d_path, imagePath)
    target_path = os.path.join(t_path, imagePath)
    
    #read the images
    img = cv2.imread(data_path)
    cb_img = cv2.imread(cb_data_path)
    target_img = cv2.imread(target_path)

    #resize the images into 224 x 224
    img = cv2.resize(img, (im_h, im_w))
    cb_img = cv2.resize(cb_img, (im_h, im_w))
    target_img = cv2.resize(target_img, (im_h, im_w))
        
    # put the images into array list
    data.append(img)
    cb_data.append(cb_img)
    target.append(target_img)

# %%
# convert arrays into numpy arrays
data = np.array(data)
cb_data = np.array(cb_data)
target = np.array(target)

print(data.shape, cb_data.shape, target.shape)
# Out:
# (712, 224, 224, 3) (712, 224, 224, 3) (712, 224, 224, 3)

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4/'

# save the numpy arrays
np.save('data', data)
np.save('cb_data', cb_data)
np.save('target', target)
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4/'

# load the numpy arrays
data = np.load('data.npy')
cb_data = np.load('cb_data.npy')
target = np.load('target.npy')

print(data.shape, cb_data.shape, target.shape)
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4
# (712, 224, 224, 3) (712, 224, 224, 3) (712, 224, 224, 3)

# %%
im_h = 224
im_w = 224

# initiate keras tensor input_sample, input_cb_sample, and output_
input_sample = Input(shape=(im_h, im_w, 3))
input_cb_sample = Input(shape=(im_h, im_w, 3))
output_ = cnn_model(input_sample, input_cb_sample)

# create the model in function way by specfying input and output
model_enhancer = Model(inputs=[input_sample, input_cb_sample], outputs=output_)

# Configures the model for training with loss function and optimizer

model_enhancer.compile(loss='mse', optimizer='adam', metrics=['mse', 'accuracy'])
model_enhancer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 16) 2368        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 16) 2368        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 224, 224, 16) 64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 12832       batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 32) 12832       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 224, 224, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 64) 18496       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 224, 224, 64) 18496       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 224, 224, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 224, 224, 64) 0           batch_normalization_2[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 224, 224, 16) 9232        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 224, 224, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 224, 224, 16) 2320        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 224, 224, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 224, 224, 3)  435         batch_normalization_7[0][0]
# ==================================================================================================
# Total params: 80,403
# Trainable params: 79,891
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
plot_model(model_enhancer, to_file='/content/drive/MyDrive/UnderwaterImageEnhancement/models/model4_view.png', show_shapes=True, show_layer_names=True)
Image(retina=True, filename='/content/drive/MyDrive/UnderwaterImageEnhancement/models/model4_view.png')

# %%
# split training dataset into 80% for training and 20% for validation
train_data, val_data, train_cb_data, val_cb_data, train_target, val_target = train_test_split(data,
                                                                                              cb_data,
                                                                                              target,
                                                                                              test_size=0.2)

print(len(train_data), len(train_cb_data), len(train_target), len(val_data), len(val_cb_data), len(val_target))
# Out:
# 569 569 569 143 143 143

# %%
epoch = 100

#
# checkpoint = ModelCheckpoint('/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/model-{epoch:03d}.h5', monitor="val_loss", save_best_only=False, mode='auto', save_freq=epoch)

# train the model
# history = model_enhancer.fit([train_data, train_cb_data], train_target, validation_data=([val_data, val_cb_data], val_target), batch_size=16, epochs=epoch, callbacks=[checkpoint], shuffle=True)


checkpoint_path = "/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss',mode='min', save_best_only=True, verbose=1)

# train the model
history = model_enhancer.fit([train_data, train_cb_data], train_target, validation_data=([val_data, val_cb_data], val_target), batch_size=16, epochs=epoch, callbacks=[cp_callback], shuffle=True)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 53s 575ms/step - loss: 16193.0088 - mse: 16193.0098 - accuracy: 0.3910 - val_loss: 13911.2646 - val_mse: 13911.2656 - val_accuracy: 0.6592
#
# Epoch 00001: val_loss improved from inf to 13911.26465, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 36/36 [==============================] - 15s 415ms/step - loss: 15519.3145 - mse: 15519.3145 - accuracy: 0.4479 - val_loss: 13497.3320 - val_mse: 13497.3320 - val_accuracy: 0.5965
#
# Epoch 00002: val_loss improved from 13911.26465 to 13497.33203, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 3/100
# 36/36 [==============================] - 15s 417ms/step - loss: 14695.2490 - mse: 14695.2490 - accuracy: 0.4575 - val_loss: 9118.7754 - val_mse: 9118.7754 - val_accuracy: 0.5405
#
# Epoch 00003: val_loss improved from 13497.33203 to 9118.77539, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 4/100
# 36/36 [==============================] - 15s 416ms/step - loss: 13439.5088 - mse: 13439.5068 - accuracy: 0.4819 - val_loss: 6951.8618 - val_mse: 6951.8618 - val_accuracy: 0.5365
#
# Epoch 00004: val_loss improved from 9118.77539 to 6951.86182, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 5/100
# 36/36 [==============================] - 15s 416ms/step - loss: 11944.4512 - mse: 11944.4492 - accuracy: 0.4939 - val_loss: 6699.0161 - val_mse: 6699.0156 - val_accuracy: 0.5173
#
# Epoch 00005: val_loss improved from 6951.86182 to 6699.01611, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 6/100
# 36/36 [==============================] - 15s 416ms/step - loss: 10471.0986 - mse: 10471.0986 - accuracy: 0.4925 - val_loss: 4992.9844 - val_mse: 4992.9849 - val_accuracy: 0.5160
#
# Epoch 00006: val_loss improved from 6699.01611 to 4992.98438, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 7/100
# 36/36 [==============================] - 15s 417ms/step - loss: 9061.5010 - mse: 9061.5010 - accuracy: 0.4925 - val_loss: 4575.6348 - val_mse: 4575.6348 - val_accuracy: 0.5165
#
# Epoch 00007: val_loss improved from 4992.98438 to 4575.63477, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 8/100
# 36/36 [==============================] - 15s 415ms/step - loss: 7754.3999 - mse: 7754.4014 - accuracy: 0.4920 - val_loss: 3419.1699 - val_mse: 3419.1699 - val_accuracy: 0.5157
#
# Epoch 00008: val_loss improved from 4575.63477 to 3419.16992, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 9/100
# 36/36 [==============================] - 15s 416ms/step - loss: 6588.5361 - mse: 6588.5356 - accuracy: 0.4919 - val_loss: 2582.5679 - val_mse: 2582.5681 - val_accuracy: 0.5157
#
# Epoch 00009: val_loss improved from 3419.16992 to 2582.56787, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 10/100
# 36/36 [==============================] - 15s 416ms/step - loss: 5533.7192 - mse: 5533.7192 - accuracy: 0.4919 - val_loss: 2506.8579 - val_mse: 2506.8579 - val_accuracy: 0.5160
#
# Epoch 00010: val_loss improved from 2582.56787 to 2506.85791, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 11/100
# 36/36 [==============================] - 15s 417ms/step - loss: 4666.1084 - mse: 4666.1079 - accuracy: 0.4917 - val_loss: 2039.4434 - val_mse: 2039.4434 - val_accuracy: 0.5167
#
# Epoch 00011: val_loss improved from 2506.85791 to 2039.44336, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 12/100
# 36/36 [==============================] - 15s 416ms/step - loss: 3944.7795 - mse: 3944.7798 - accuracy: 0.4922 - val_loss: 1806.3959 - val_mse: 1806.3959 - val_accuracy: 0.5159
#
# Epoch 00012: val_loss improved from 2039.44336 to 1806.39587, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 13/100
# 36/36 [==============================] - 15s 416ms/step - loss: 3349.9915 - mse: 3349.9917 - accuracy: 0.4920 - val_loss: 1580.6669 - val_mse: 1580.6669 - val_accuracy: 0.5159
#
# Epoch 00013: val_loss improved from 1806.39587 to 1580.66687, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 14/100
# 36/36 [==============================] - 15s 416ms/step - loss: 2891.4937 - mse: 2891.4934 - accuracy: 0.4947 - val_loss: 1750.3099 - val_mse: 1750.3099 - val_accuracy: 0.5152
#
# Epoch 00014: val_loss did not improve from 1580.66687
# Epoch 15/100
# 36/36 [==============================] - 15s 417ms/step - loss: 2518.6785 - mse: 2518.6785 - accuracy: 0.5012 - val_loss: 1690.2335 - val_mse: 1690.2336 - val_accuracy: 0.5207
#
# Epoch 00015: val_loss did not improve from 1580.66687
# Epoch 16/100
# 36/36 [==============================] - 15s 416ms/step - loss: 2213.6582 - mse: 2213.6584 - accuracy: 0.5092 - val_loss: 1523.7869 - val_mse: 1523.7867 - val_accuracy: 0.5185
#
# Epoch 00016: val_loss improved from 1580.66687 to 1523.78687, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 17/100
# 36/36 [==============================] - 15s 416ms/step - loss: 1956.9062 - mse: 1956.9066 - accuracy: 0.5231 - val_loss: 1717.3518 - val_mse: 1717.3518 - val_accuracy: 0.5481
#
# Epoch 00017: val_loss did not improve from 1523.78687
# Epoch 18/100
# 36/36 [==============================] - 15s 416ms/step - loss: 1767.7250 - mse: 1767.7249 - accuracy: 0.5389 - val_loss: 1386.3499 - val_mse: 1386.3500 - val_accuracy: 0.5580
#
# Epoch 00018: val_loss improved from 1523.78687 to 1386.34985, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 19/100
# 36/36 [==============================] - 15s 417ms/step - loss: 1604.1484 - mse: 1604.1482 - accuracy: 0.5762 - val_loss: 1530.0132 - val_mse: 1530.0133 - val_accuracy: 0.5903
#
# Epoch 00019: val_loss did not improve from 1386.34985
# Epoch 20/100
# 36/36 [==============================] - 15s 415ms/step - loss: 1481.3982 - mse: 1481.3981 - accuracy: 0.6026 - val_loss: 1193.2030 - val_mse: 1193.2031 - val_accuracy: 0.6115
#
# Epoch 00020: val_loss improved from 1386.34985 to 1193.20300, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 21/100
# 36/36 [==============================] - 15s 415ms/step - loss: 1334.2104 - mse: 1334.2108 - accuracy: 0.6332 - val_loss: 1061.6028 - val_mse: 1061.6028 - val_accuracy: 0.6391
#
# Epoch 00021: val_loss improved from 1193.20300 to 1061.60278, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 22/100
# 36/36 [==============================] - 15s 417ms/step - loss: 1209.1863 - mse: 1209.1862 - accuracy: 0.6521 - val_loss: 998.8652 - val_mse: 998.8651 - val_accuracy: 0.6731
#
# Epoch 00022: val_loss improved from 1061.60278 to 998.86517, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 23/100
# 36/36 [==============================] - 15s 416ms/step - loss: 1107.6909 - mse: 1107.6908 - accuracy: 0.6637 - val_loss: 1048.6406 - val_mse: 1048.6405 - val_accuracy: 0.6649
#
# Epoch 00023: val_loss did not improve from 998.86517
# Epoch 24/100
# 36/36 [==============================] - 15s 416ms/step - loss: 1031.2739 - mse: 1031.2738 - accuracy: 0.6718 - val_loss: 900.0269 - val_mse: 900.0269 - val_accuracy: 0.6701
#
# Epoch 00024: val_loss improved from 998.86517 to 900.02686, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 25/100
# 36/36 [==============================] - 15s 416ms/step - loss: 974.9683 - mse: 974.9683 - accuracy: 0.6720 - val_loss: 897.0431 - val_mse: 897.0430 - val_accuracy: 0.6494
#
# Epoch 00025: val_loss improved from 900.02686 to 897.04309, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 26/100
# 36/36 [==============================] - 15s 416ms/step - loss: 933.7739 - mse: 933.7740 - accuracy: 0.6726 - val_loss: 857.8903 - val_mse: 857.8903 - val_accuracy: 0.6667
#
# Epoch 00026: val_loss improved from 897.04309 to 857.89032, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 27/100
# 36/36 [==============================] - 15s 416ms/step - loss: 871.4398 - mse: 871.4398 - accuracy: 0.6860 - val_loss: 807.9948 - val_mse: 807.9947 - val_accuracy: 0.6692
#
# Epoch 00027: val_loss improved from 857.89032 to 807.99475, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 28/100
# 36/36 [==============================] - 15s 416ms/step - loss: 837.7439 - mse: 837.7441 - accuracy: 0.6943 - val_loss: 777.7559 - val_mse: 777.7560 - val_accuracy: 0.6945
#
# Epoch 00028: val_loss improved from 807.99475 to 777.75592, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 29/100
# 36/36 [==============================] - 15s 416ms/step - loss: 789.5291 - mse: 789.5290 - accuracy: 0.6964 - val_loss: 773.6633 - val_mse: 773.6632 - val_accuracy: 0.6925
#
# Epoch 00029: val_loss improved from 777.75592 to 773.66327, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 30/100
# 36/36 [==============================] - 15s 416ms/step - loss: 775.6555 - mse: 775.6556 - accuracy: 0.6934 - val_loss: 762.1934 - val_mse: 762.1934 - val_accuracy: 0.6944
#
# Epoch 00030: val_loss improved from 773.66327 to 762.19336, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 31/100
# 36/36 [==============================] - 15s 416ms/step - loss: 758.8769 - mse: 758.8767 - accuracy: 0.6971 - val_loss: 759.0546 - val_mse: 759.0546 - val_accuracy: 0.6899
#
# Epoch 00031: val_loss improved from 762.19336 to 759.05463, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 32/100
# 36/36 [==============================] - 15s 415ms/step - loss: 739.6945 - mse: 739.6946 - accuracy: 0.7045 - val_loss: 734.1471 - val_mse: 734.1471 - val_accuracy: 0.6977
#
# Epoch 00032: val_loss improved from 759.05463 to 734.14709, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 33/100
# 36/36 [==============================] - 15s 416ms/step - loss: 715.0619 - mse: 715.0618 - accuracy: 0.7138 - val_loss: 786.3704 - val_mse: 786.3704 - val_accuracy: 0.6843
#
# Epoch 00033: val_loss did not improve from 734.14709
# Epoch 34/100
# 36/36 [==============================] - 15s 417ms/step - loss: 733.5041 - mse: 733.5040 - accuracy: 0.7128 - val_loss: 788.5614 - val_mse: 788.5615 - val_accuracy: 0.7017
#
# Epoch 00034: val_loss did not improve from 734.14709
# Epoch 35/100
# 36/36 [==============================] - 15s 418ms/step - loss: 720.3381 - mse: 720.3381 - accuracy: 0.7100 - val_loss: 764.1982 - val_mse: 764.1982 - val_accuracy: 0.6983
#
# Epoch 00035: val_loss did not improve from 734.14709
# Epoch 36/100
# 36/36 [==============================] - 15s 415ms/step - loss: 694.9695 - mse: 694.9695 - accuracy: 0.7237 - val_loss: 713.2720 - val_mse: 713.2720 - val_accuracy: 0.7087
#
# Epoch 00036: val_loss improved from 734.14709 to 713.27197, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 37/100
# 36/36 [==============================] - 15s 416ms/step - loss: 685.8359 - mse: 685.8359 - accuracy: 0.7247 - val_loss: 739.6538 - val_mse: 739.6539 - val_accuracy: 0.7233
#
# Epoch 00037: val_loss did not improve from 713.27197
# Epoch 38/100
# 36/36 [==============================] - 15s 416ms/step - loss: 674.4762 - mse: 674.4763 - accuracy: 0.7211 - val_loss: 796.3533 - val_mse: 796.3533 - val_accuracy: 0.7223
#
# Epoch 00038: val_loss did not improve from 713.27197
# Epoch 39/100
# 36/36 [==============================] - 15s 416ms/step - loss: 649.6179 - mse: 649.6178 - accuracy: 0.7370 - val_loss: 680.2869 - val_mse: 680.2869 - val_accuracy: 0.7423
#
# Epoch 00039: val_loss improved from 713.27197 to 680.28693, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 40/100
# 36/36 [==============================] - 15s 415ms/step - loss: 660.6779 - mse: 660.6778 - accuracy: 0.7350 - val_loss: 726.8876 - val_mse: 726.8875 - val_accuracy: 0.7371
#
# Epoch 00040: val_loss did not improve from 680.28693
# Epoch 41/100
# 36/36 [==============================] - 15s 416ms/step - loss: 657.1307 - mse: 657.1307 - accuracy: 0.7363 - val_loss: 733.6093 - val_mse: 733.6094 - val_accuracy: 0.7046
#
# Epoch 00041: val_loss did not improve from 680.28693
# Epoch 42/100
# 36/36 [==============================] - 15s 415ms/step - loss: 669.1980 - mse: 669.1979 - accuracy: 0.7358 - val_loss: 685.2939 - val_mse: 685.2938 - val_accuracy: 0.7228
#
# Epoch 00042: val_loss did not improve from 680.28693
# Epoch 43/100
# 36/36 [==============================] - 15s 416ms/step - loss: 652.3435 - mse: 652.3434 - accuracy: 0.7351 - val_loss: 872.2974 - val_mse: 872.2974 - val_accuracy: 0.7249
#
# Epoch 00043: val_loss did not improve from 680.28693
# Epoch 44/100
# 36/36 [==============================] - 15s 415ms/step - loss: 652.1711 - mse: 652.1710 - accuracy: 0.7399 - val_loss: 674.5596 - val_mse: 674.5598 - val_accuracy: 0.6800
#
# Epoch 00044: val_loss improved from 680.28693 to 674.55963, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 45/100
# 36/36 [==============================] - 15s 416ms/step - loss: 639.5307 - mse: 639.5307 - accuracy: 0.7450 - val_loss: 847.9073 - val_mse: 847.9073 - val_accuracy: 0.7363
#
# Epoch 00045: val_loss did not improve from 674.55963
# Epoch 46/100
# 36/36 [==============================] - 15s 416ms/step - loss: 644.3792 - mse: 644.3792 - accuracy: 0.7454 - val_loss: 634.2402 - val_mse: 634.2401 - val_accuracy: 0.7415
#
# Epoch 00046: val_loss improved from 674.55963 to 634.24017, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 47/100
# 36/36 [==============================] - 15s 416ms/step - loss: 630.5134 - mse: 630.5132 - accuracy: 0.7465 - val_loss: 628.6952 - val_mse: 628.6952 - val_accuracy: 0.7397
#
# Epoch 00047: val_loss improved from 634.24017 to 628.69519, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 48/100
# 36/36 [==============================] - 15s 415ms/step - loss: 627.7799 - mse: 627.7800 - accuracy: 0.7466 - val_loss: 714.0355 - val_mse: 714.0355 - val_accuracy: 0.7167
#
# Epoch 00048: val_loss did not improve from 628.69519
# Epoch 49/100
# 36/36 [==============================] - 15s 415ms/step - loss: 636.2227 - mse: 636.2227 - accuracy: 0.7432 - val_loss: 905.8655 - val_mse: 905.8655 - val_accuracy: 0.6587
#
# Epoch 00049: val_loss did not improve from 628.69519
# Epoch 50/100
# 36/36 [==============================] - 15s 416ms/step - loss: 614.5393 - mse: 614.5394 - accuracy: 0.7407 - val_loss: 679.0244 - val_mse: 679.0244 - val_accuracy: 0.6908
#
# Epoch 00050: val_loss did not improve from 628.69519
# Epoch 51/100
# 36/36 [==============================] - 15s 416ms/step - loss: 621.2604 - mse: 621.2606 - accuracy: 0.7434 - val_loss: 649.7952 - val_mse: 649.7952 - val_accuracy: 0.7387
#
# Epoch 00051: val_loss did not improve from 628.69519
# Epoch 52/100
# 36/36 [==============================] - 15s 415ms/step - loss: 636.6557 - mse: 636.6557 - accuracy: 0.7448 - val_loss: 685.1790 - val_mse: 685.1790 - val_accuracy: 0.7151
#
# Epoch 00052: val_loss did not improve from 628.69519
# Epoch 53/100
# 36/36 [==============================] - 15s 416ms/step - loss: 665.1666 - mse: 665.1666 - accuracy: 0.7422 - val_loss: 723.8595 - val_mse: 723.8596 - val_accuracy: 0.7070
#
# Epoch 00053: val_loss did not improve from 628.69519
# Epoch 54/100
# 36/36 [==============================] - 15s 416ms/step - loss: 642.1037 - mse: 642.1036 - accuracy: 0.7448 - val_loss: 751.8006 - val_mse: 751.8005 - val_accuracy: 0.7339
#
# Epoch 00054: val_loss did not improve from 628.69519
# Epoch 55/100
# 36/36 [==============================] - 15s 415ms/step - loss: 618.7575 - mse: 618.7577 - accuracy: 0.7457 - val_loss: 679.5181 - val_mse: 679.5181 - val_accuracy: 0.7231
#
# Epoch 00055: val_loss did not improve from 628.69519
# Epoch 56/100
# 36/36 [==============================] - 15s 414ms/step - loss: 616.1949 - mse: 616.1948 - accuracy: 0.7463 - val_loss: 614.1308 - val_mse: 614.1308 - val_accuracy: 0.7461
#
# Epoch 00056: val_loss improved from 628.69519 to 614.13080, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 57/100
# 36/36 [==============================] - 15s 416ms/step - loss: 605.4395 - mse: 605.4396 - accuracy: 0.7482 - val_loss: 746.9371 - val_mse: 746.9371 - val_accuracy: 0.6955
#
# Epoch 00057: val_loss did not improve from 614.13080
# Epoch 58/100
# 36/36 [==============================] - 15s 416ms/step - loss: 603.9421 - mse: 603.9421 - accuracy: 0.7502 - val_loss: 685.1757 - val_mse: 685.1756 - val_accuracy: 0.7051
#
# Epoch 00058: val_loss did not improve from 614.13080
# Epoch 59/100
# 36/36 [==============================] - 15s 417ms/step - loss: 626.4086 - mse: 626.4087 - accuracy: 0.7399 - val_loss: 639.9216 - val_mse: 639.9216 - val_accuracy: 0.7393
#
# Epoch 00059: val_loss did not improve from 614.13080
# Epoch 60/100
# 36/36 [==============================] - 15s 416ms/step - loss: 612.7678 - mse: 612.7680 - accuracy: 0.7470 - val_loss: 610.5978 - val_mse: 610.5978 - val_accuracy: 0.7602
#
# Epoch 00060: val_loss improved from 614.13080 to 610.59778, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 61/100
# 36/36 [==============================] - 15s 416ms/step - loss: 607.8792 - mse: 607.8792 - accuracy: 0.7485 - val_loss: 769.5834 - val_mse: 769.5834 - val_accuracy: 0.7155
#
# Epoch 00061: val_loss did not improve from 610.59778
# Epoch 62/100
# 36/36 [==============================] - 15s 416ms/step - loss: 588.7716 - mse: 588.7716 - accuracy: 0.7556 - val_loss: 635.3609 - val_mse: 635.3608 - val_accuracy: 0.7355
#
# Epoch 00062: val_loss did not improve from 610.59778
# Epoch 63/100
# 36/36 [==============================] - 15s 416ms/step - loss: 601.5001 - mse: 601.5001 - accuracy: 0.7424 - val_loss: 599.9299 - val_mse: 599.9300 - val_accuracy: 0.7282
#
# Epoch 00063: val_loss improved from 610.59778 to 599.92993, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 64/100
# 36/36 [==============================] - 15s 415ms/step - loss: 596.6419 - mse: 596.6418 - accuracy: 0.7513 - val_loss: 635.7830 - val_mse: 635.7830 - val_accuracy: 0.7570
#
# Epoch 00064: val_loss did not improve from 599.92993
# Epoch 65/100
# 36/36 [==============================] - 15s 415ms/step - loss: 599.0049 - mse: 599.0049 - accuracy: 0.7528 - val_loss: 766.2736 - val_mse: 766.2735 - val_accuracy: 0.7193
#
# Epoch 00065: val_loss did not improve from 599.92993
# Epoch 66/100
# 36/36 [==============================] - 15s 416ms/step - loss: 622.9680 - mse: 622.9681 - accuracy: 0.7480 - val_loss: 745.1869 - val_mse: 745.1870 - val_accuracy: 0.7234
#
# Epoch 00066: val_loss did not improve from 599.92993
# Epoch 67/100
# 36/36 [==============================] - 15s 416ms/step - loss: 602.8807 - mse: 602.8810 - accuracy: 0.7476 - val_loss: 680.9835 - val_mse: 680.9834 - val_accuracy: 0.7335
#
# Epoch 00067: val_loss did not improve from 599.92993
# Epoch 68/100
# 36/36 [==============================] - 15s 415ms/step - loss: 615.7679 - mse: 615.7679 - accuracy: 0.7455 - val_loss: 658.3211 - val_mse: 658.3211 - val_accuracy: 0.7338
#
# Epoch 00068: val_loss did not improve from 599.92993
# Epoch 69/100
# 36/36 [==============================] - 15s 418ms/step - loss: 597.1321 - mse: 597.1321 - accuracy: 0.7484 - val_loss: 632.8150 - val_mse: 632.8151 - val_accuracy: 0.7576
#
# Epoch 00069: val_loss did not improve from 599.92993
# Epoch 70/100
# 36/36 [==============================] - 15s 417ms/step - loss: 592.5920 - mse: 592.5919 - accuracy: 0.7544 - val_loss: 632.0099 - val_mse: 632.0098 - val_accuracy: 0.7303
#
# Epoch 00070: val_loss did not improve from 599.92993
# Epoch 71/100
# 36/36 [==============================] - 15s 417ms/step - loss: 592.7452 - mse: 592.7453 - accuracy: 0.7504 - val_loss: 637.4595 - val_mse: 637.4595 - val_accuracy: 0.7423
#
# Epoch 00071: val_loss did not improve from 599.92993
# Epoch 72/100
# 36/36 [==============================] - 15s 416ms/step - loss: 588.0623 - mse: 588.0621 - accuracy: 0.7430 - val_loss: 609.5558 - val_mse: 609.5558 - val_accuracy: 0.7467
#
# Epoch 00072: val_loss did not improve from 599.92993
# Epoch 73/100
# 36/36 [==============================] - 15s 417ms/step - loss: 590.9590 - mse: 590.9592 - accuracy: 0.7565 - val_loss: 615.5255 - val_mse: 615.5254 - val_accuracy: 0.7311
#
# Epoch 00073: val_loss did not improve from 599.92993
# Epoch 74/100
# 36/36 [==============================] - 15s 416ms/step - loss: 584.3303 - mse: 584.3303 - accuracy: 0.7503 - val_loss: 604.8880 - val_mse: 604.8881 - val_accuracy: 0.7398
#
# Epoch 00074: val_loss did not improve from 599.92993
# Epoch 75/100
# 36/36 [==============================] - 15s 416ms/step - loss: 581.1178 - mse: 581.1178 - accuracy: 0.7504 - val_loss: 596.4682 - val_mse: 596.4681 - val_accuracy: 0.7658
#
# Epoch 00075: val_loss improved from 599.92993 to 596.46820, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 76/100
# 36/36 [==============================] - 15s 415ms/step - loss: 577.2452 - mse: 577.2453 - accuracy: 0.7539 - val_loss: 659.8064 - val_mse: 659.8063 - val_accuracy: 0.7342
#
# Epoch 00076: val_loss did not improve from 596.46820
# Epoch 77/100
# 36/36 [==============================] - 15s 417ms/step - loss: 573.8535 - mse: 573.8535 - accuracy: 0.7530 - val_loss: 639.7719 - val_mse: 639.7720 - val_accuracy: 0.7390
#
# Epoch 00077: val_loss did not improve from 596.46820
# Epoch 78/100
# 36/36 [==============================] - 15s 416ms/step - loss: 586.1387 - mse: 586.1386 - accuracy: 0.7602 - val_loss: 625.1508 - val_mse: 625.1509 - val_accuracy: 0.7492
#
# Epoch 00078: val_loss did not improve from 596.46820
# Epoch 79/100
# 36/36 [==============================] - 15s 417ms/step - loss: 575.0512 - mse: 575.0511 - accuracy: 0.7526 - val_loss: 603.3016 - val_mse: 603.3016 - val_accuracy: 0.7464
#
# Epoch 00079: val_loss did not improve from 596.46820
# Epoch 80/100
# 36/36 [==============================] - 15s 416ms/step - loss: 589.4856 - mse: 589.4856 - accuracy: 0.7444 - val_loss: 614.8558 - val_mse: 614.8558 - val_accuracy: 0.7419
#
# Epoch 00080: val_loss did not improve from 596.46820
# Epoch 81/100
# 36/36 [==============================] - 15s 417ms/step - loss: 561.7172 - mse: 561.7171 - accuracy: 0.7482 - val_loss: 636.5919 - val_mse: 636.5919 - val_accuracy: 0.7525
#
# Epoch 00081: val_loss did not improve from 596.46820
# Epoch 82/100
# 36/36 [==============================] - 15s 416ms/step - loss: 568.7817 - mse: 568.7816 - accuracy: 0.7538 - val_loss: 596.7334 - val_mse: 596.7334 - val_accuracy: 0.7477
#
# Epoch 00082: val_loss did not improve from 596.46820
# Epoch 83/100
# 36/36 [==============================] - 15s 417ms/step - loss: 555.2805 - mse: 555.2805 - accuracy: 0.7538 - val_loss: 619.5475 - val_mse: 619.5474 - val_accuracy: 0.7373
#
# Epoch 00083: val_loss did not improve from 596.46820
# Epoch 84/100
# 36/36 [==============================] - 15s 415ms/step - loss: 576.1379 - mse: 576.1379 - accuracy: 0.7507 - val_loss: 580.9921 - val_mse: 580.9921 - val_accuracy: 0.7638
#
# Epoch 00084: val_loss improved from 596.46820 to 580.99213, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 85/100
# 36/36 [==============================] - 15s 417ms/step - loss: 573.4005 - mse: 573.4006 - accuracy: 0.7574 - val_loss: 604.1435 - val_mse: 604.1435 - val_accuracy: 0.7443
#
# Epoch 00085: val_loss did not improve from 580.99213
# Epoch 86/100
# 36/36 [==============================] - 15s 417ms/step - loss: 554.6149 - mse: 554.6149 - accuracy: 0.7519 - val_loss: 644.2333 - val_mse: 644.2333 - val_accuracy: 0.7543
#
# Epoch 00086: val_loss did not improve from 580.99213
# Epoch 87/100
# 36/36 [==============================] - 15s 417ms/step - loss: 575.6269 - mse: 575.6270 - accuracy: 0.7526 - val_loss: 628.6777 - val_mse: 628.6777 - val_accuracy: 0.7434
#
# Epoch 00087: val_loss did not improve from 580.99213
# Epoch 88/100
# 36/36 [==============================] - 15s 417ms/step - loss: 581.9957 - mse: 581.9957 - accuracy: 0.7471 - val_loss: 600.2034 - val_mse: 600.2033 - val_accuracy: 0.7416
#
# Epoch 00088: val_loss did not improve from 580.99213
# Epoch 89/100
# 36/36 [==============================] - 15s 416ms/step - loss: 559.2512 - mse: 559.2512 - accuracy: 0.7525 - val_loss: 787.8140 - val_mse: 787.8140 - val_accuracy: 0.7131
#
# Epoch 00089: val_loss did not improve from 580.99213
# Epoch 90/100
# 36/36 [==============================] - 15s 422ms/step - loss: 566.6463 - mse: 566.6463 - accuracy: 0.7605 - val_loss: 596.0169 - val_mse: 596.0168 - val_accuracy: 0.7380
#
# Epoch 00090: val_loss did not improve from 580.99213
# Epoch 91/100
# 36/36 [==============================] - 15s 416ms/step - loss: 574.4792 - mse: 574.4794 - accuracy: 0.7590 - val_loss: 627.6414 - val_mse: 627.6414 - val_accuracy: 0.7407
#
# Epoch 00091: val_loss did not improve from 580.99213
# Epoch 92/100
# 36/36 [==============================] - 15s 415ms/step - loss: 567.2162 - mse: 567.2162 - accuracy: 0.7511 - val_loss: 623.2507 - val_mse: 623.2506 - val_accuracy: 0.7600
#
# Epoch 00092: val_loss did not improve from 580.99213
# Epoch 93/100
# 36/36 [==============================] - 15s 416ms/step - loss: 548.0419 - mse: 548.0418 - accuracy: 0.7538 - val_loss: 637.9616 - val_mse: 637.9615 - val_accuracy: 0.7568
#
# Epoch 00093: val_loss did not improve from 580.99213
# Epoch 94/100
# 36/36 [==============================] - 15s 416ms/step - loss: 564.4446 - mse: 564.4446 - accuracy: 0.7545 - val_loss: 585.2725 - val_mse: 585.2725 - val_accuracy: 0.7542
#
# Epoch 00094: val_loss did not improve from 580.99213
# Epoch 95/100
# 36/36 [==============================] - 15s 417ms/step - loss: 559.5764 - mse: 559.5765 - accuracy: 0.7578 - val_loss: 593.2170 - val_mse: 593.2171 - val_accuracy: 0.7613
#
# Epoch 00095: val_loss did not improve from 580.99213
# Epoch 96/100
# 36/36 [==============================] - 15s 416ms/step - loss: 558.2449 - mse: 558.2450 - accuracy: 0.7535 - val_loss: 598.0048 - val_mse: 598.0048 - val_accuracy: 0.7643
#
# Epoch 00096: val_loss did not improve from 580.99213
# Epoch 97/100
# 36/36 [==============================] - 15s 416ms/step - loss: 546.5380 - mse: 546.5380 - accuracy: 0.7559 - val_loss: 610.9129 - val_mse: 610.9129 - val_accuracy: 0.7595
#
# Epoch 00097: val_loss did not improve from 580.99213
# Epoch 98/100
# 36/36 [==============================] - 15s 422ms/step - loss: 562.3363 - mse: 562.3365 - accuracy: 0.7550 - val_loss: 569.6842 - val_mse: 569.6841 - val_accuracy: 0.7663
#
# Epoch 00098: val_loss improved from 580.99213 to 569.68420, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5
# Epoch 99/100
# 36/36 [==============================] - 15s 417ms/step - loss: 549.6498 - mse: 549.6499 - accuracy: 0.7599 - val_loss: 650.3812 - val_mse: 650.3812 - val_accuracy: 0.7469
#
# Epoch 00099: val_loss did not improve from 569.68420
# Epoch 100/100
# 36/36 [==============================] - 15s 417ms/step - loss: 565.9586 - mse: 565.9587 - accuracy: 0.7547 - val_loss: 584.0446 - val_mse: 584.0446 - val_accuracy: 0.7205
#
# Epoch 00100: val_loss did not improve from 569.68420

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'accuracy', 'val_loss', 'val_mse', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='validation')
plt.legend()
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
###################################################################################################### TESTING PART ####################################################################################################

# %%
###### How to load and use weights from a checkpoint #########

im_h = 224
im_w = 224

# initiate keras tensor input_sample, input_cb_sample, and output_
input_sample = Input(shape=(im_h, im_w, 3))
input_cb_sample = Input(shape=(im_h, im_w, 3))
output_ = cnn_model(input_sample, input_cb_sample)

# create the model in function way by specfying input and output
model_enhancer_test = Model(inputs=[input_sample, input_cb_sample], outputs=output_)

# load weights
model_enhancer_test.load_weights("/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model4/weights_best.hdf5")

# Configures the model for training with loss function and optimizer
model_enhancer_test.compile(loss='mse', optimizer='adam', metrics=['mse', 'accuracy'])

# %%
############################################################# Evaluate the model in testing part

d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/raw'
cb_d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/cb_raw'
t_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'

data = []
cb_data = []
target = []

im_h = 224
im_w = 224
for imagePath in os.listdir(d_path):

    # get full the path of the raw(real), cb_raw(color balancing real) and reference(target) images
    data_path = os.path.join(d_path, imagePath)
    cb_data_path = os.path.join(cb_d_path, imagePath)
    target_path = os.path.join(t_path, imagePath)
    
    #read the images
    img = cv2.imread(data_path)
    cb_img = cv2.imread(cb_data_path)
    target_img = cv2.imread(target_path)

    #resize the images 
    img = cv2.resize(img, (im_h, im_w))
    cb_img = cv2.resize(cb_img, (im_h, im_w))
    target_img = cv2.resize(target_img, (im_h, im_w))
        
    # put the images into array list
    data.append(img)
    cb_data.append(cb_img)
    target.append(target_img)


# convert arrays into numpy arrays
test_data = np.array(data)
test_cb_data = np.array(cb_data)
test_target = np.array(target)

print(test_data.shape, test_cb_data.shape, test_target.shape)

# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4/'

# save the numpy arrays
np.save('test_data', test_data)
np.save('test_cb_data', test_cb_data)
np.save('test_target', test_target)
# Out:
# (178, 224, 224, 3) (178, 224, 224, 3) (178, 224, 224, 3)
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4/'

# load the numpy arrays
test_data = np.load('test_data.npy')
test_cb_data = np.load('test_cb_data.npy')
test_target = np.load('test_target.npy')

print(test_data.shape, test_cb_data.shape, test_target.shape)


# estimate accuracy and the MSE on test dataset using loaded weights
scores = model_enhancer_test.evaluate([test_data, test_cb_data ], test_target, verbose=0)

#print("%s: %.2f%%" % (model_enhancer_test.metrics_names[2], scores[2]*100))
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model4
# (178, 224, 224, 3) (178, 224, 224, 3) (178, 224, 224, 3)

# %%
# Testing Accuracy
print("%s: %.2f%%" % (model_enhancer_test.metrics_names[2], scores[2]*100))
# Out:
# accuracy: 74.02%

# %%
############################################################## predict the data using loaded weights

import numpy as np
from PIL import Image
import cv2
import os
from matplotlib import pyplot as plt


test_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/raw/'
cb_test_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/cb_raw'
destination = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model4-output/'

im_h = 224
im_w = 224
for test_img_name in os.listdir(test_path):

    #read the raw images
    test_img = cv2.imread(os.path.join(test_path, test_img_name))
    cb_test_img = cv2.imread(os.path.join(cb_test_path, test_img_name))
   
    #resize the images into 224 x 224
    test_img = cv2.resize(test_img, (im_h, im_w))
    cb_test_img = cv2.resize(cb_test_img, (im_h, im_w))
    
    # reshape the image (224, 224, 3) into (1, 224, 224, 3)
    test_img = test_img.reshape(1,im_h, im_w,3)
    cb_test_img = cb_test_img.reshape(1,im_h, im_w,3)

    
    # use model to do prediction
    #result = model_enhancer.predict([test_img, cb_test_img])
    result = model_enhancer_test.predict([test_img, cb_test_img])
    #
    result = result.squeeze()
    
    test_img = test_img.squeeze()
    
    test_img[:,:,:] = result[:,:,:]
    #plt.imshow(test_img)
    cv2.imwrite(os.path.join(destination, test_img_name), test_img)

# %%
###### FULL-REFERENCE IMAGE QUALITY ASSESSMENT IN TERMS OF MSE, PSNR, AND SSIM #######

import numpy as np
import cv2
import os

from skimage.metrics import mean_squared_error
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity 


target_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'
predicted_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model4-output/'



im_h = 224
im_w = 224

sumMSE = 0;
sumPSNR = 0;
sumSSIM = 0;
count = 0;


for image_name in os.listdir(target_path):

    #read the raw images
    target_img = cv2.imread(os.path.join(target_path, image_name))
    predicted_img = cv2.imread(os.path.join(predicted_path, image_name))
    

    #resize the images into 224 x 224
    target_img = cv2.resize(target_img, (im_h, im_w))
    predicted_img = cv2.resize(predicted_img, (im_h, im_w))


    #calculate the MSE, PSNR, and SSIM 
    MSE = mean_squared_error(target_img, predicted_img)
    PSNR = peak_signal_noise_ratio(target_img, predicted_img)
    SSIM = structural_similarity(target_img, predicted_img, multichannel=True)

    sumMSE = sumMSE + MSE
    sumPSNR = sumPSNR + PSNR
    sumSSIM = sumSSIM + SSIM
    count = count + 1
    
    # print('SSIM: ', SSIM)
    # print('MSE: ', MSE)
    # print('PSNR: ', PSNR)


# print('sumMSE: ',sumMSE)
# print('sumPSNR: ', sumPSNR)
# print('sumSSIM: ', sumSSIM)
# print('count: ', count)


# Get the Average value 
mse_value = sumMSE/count
psnr_value = sumPSNR/count
ssim_value = sumSSIM/count


print("MSE for testing data :", format(mse_value, ".4f"))
print("PSNR for testing data :", format(psnr_value, ".4f"), "dB")
print("SSIM for testing data :", format(ssim_value, ".4f"))
# Out:
# MSE for testing data : 623.2324
# PSNR for testing data : 21.5522 dB
# SSIM for testing data : 0.8651
