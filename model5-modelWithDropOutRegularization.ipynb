# %%
import imageio
import cv2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from matplotlib import pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
K.clear_session()

def cnn_model(img, cb_img):
    
    conv_1 = Conv2D(16, (7, 7), activation='relu', padding='same', strides=1)(img)
    conv_1 = Conv2D(32, (5, 5), activation='relu', padding='same', strides=1)(conv_1)
    conv_1 = Conv2D(64, (3, 3), activation='relu', padding='same', strides=1)(conv_1)
   

    conv_2 = Conv2D(16, (7, 7), activation='relu', padding='same', strides=1)(cb_img)
    conv_2 = Conv2D(32, (5, 5), activation='relu', padding='same', strides=1)(conv_2)
    conv_2 = Conv2D(64, (3, 3), activation='relu', padding='same', strides=1)(conv_2)
   
    add_1 = tf.keras.layers.Add()([conv_1, conv_2])

    conv_3 = Conv2D(16, (3, 3), activation='relu', padding='same', strides=1)(add_1)
    conv_4 = Conv2D(16, (3, 3), activation='relu', padding='same', strides=1)(conv_3)
    drop_out_1 = Dropout(0.2)(conv_4)
    conv_5 = Conv2D(3, (3, 3), activation='relu', padding='same', strides=1)(drop_out_1)
  
    return conv_5

# %%
############################################################################################################# TRAINING PART ################################################################################################

# %%
d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/raw'
cb_d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/cb_raw'
t_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/train-set/reference'

data = []
cb_data = []
target = []

im_h = 224
im_w = 224
for imagePath in os.listdir(d_path):

    # get full the path of the raw(real), cb_raw(color balancing real) and reference(target) images
    data_path = os.path.join(d_path, imagePath)
    cb_data_path = os.path.join(cb_d_path, imagePath)
    target_path = os.path.join(t_path, imagePath)
    
    #read the images
    img = cv2.imread(data_path)
    cb_img = cv2.imread(cb_data_path)
    target_img = cv2.imread(target_path)

    #resize the images into 112 x 112
    img = cv2.resize(img, (im_h, im_w))
    cb_img = cv2.resize(cb_img, (im_h, im_w))
    target_img = cv2.resize(target_img, (im_h, im_w))
        
    # put the images into array list
    data.append(img)
    cb_data.append(cb_img)
    target.append(target_img)

# %%
# convert arrays into numpy arrays
data = np.array(data)
cb_data = np.array(cb_data)
target = np.array(target)

print(data.shape, cb_data.shape, target.shape)
# Out:
# (712, 224, 224, 3) (712, 224, 224, 3) (712, 224, 224, 3)

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5/'

# save the numpy arrays
np.save('data', data)
np.save('cb_data', cb_data)
np.save('target', target)
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5/'

# load the numpy arrays
data = np.load('data.npy')
cb_data = np.load('cb_data.npy')
target = np.load('target.npy')

print(data.shape, cb_data.shape, target.shape)
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5
# (712, 224, 224, 3) (712, 224, 224, 3) (712, 224, 224, 3)

# %%
im_h = 224
im_w = 224

# initiate keras tensor input_sample, input_cb_sample, and output_
input_sample = Input(shape=(im_h, im_w, 3))
input_cb_sample = Input(shape=(im_h, im_w, 3))
output_ = cnn_model(input_sample, input_cb_sample)

# create the model in function way by specfying input and output
model_enhancer = Model(inputs=[input_sample, input_cb_sample], outputs=output_)

# Configures the model for training with loss function and optimizer
model_enhancer.compile(loss='mse', optimizer='adam', metrics=['mse', 'accuracy'])
model_enhancer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 16) 2368        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 16) 2368        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 12832       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 32) 12832       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 64) 18496       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 224, 224, 64) 18496       conv2d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 224, 224, 64) 0           conv2d_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 224, 224, 16) 9232        add[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 224, 224, 16) 2320        conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 224, 224, 16) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 224, 224, 3)  435         dropout[0][0]
# ==================================================================================================
# Total params: 79,379
# Trainable params: 79,379
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_enhancer, to_file='/content/drive/MyDrive/UnderwaterImageEnhancement/models/model5_view.png', show_shapes=True, show_layer_names=True)
Image(retina=True, filename='/content/drive/MyDrive/UnderwaterImageEnhancement/models/model5_view.png')

# %%
# split training dataset into 80% for training and 20% for validation
train_data, val_data, train_cb_data, val_cb_data, train_target, val_target = train_test_split(data,
                                                                                              cb_data,
                                                                                              target,
                                                                                              test_size=0.2)

print(len(train_data), len(train_cb_data), len(train_target), len(val_data), len(val_cb_data), len(val_target))
# Out:
# 569 569 569 143 143 143

# %%
epoch = 100

#
#checkpoint = ModelCheckpoint('/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/model-{epoch:03d}.h5', monitor="val_loss", save_best_only=False, mode='auto', save_freq=epoch)

# train the model
#history = model_enhancer.fit([train_data, train_cb_data], train_target, validation_data=([val_data, val_cb_data], val_target), batch_size=16, epochs=epoch, callbacks=[checkpoint], shuffle=True)



checkpoint_path = "/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss',mode='min', save_best_only=True, verbose=1)

# train the model
history = model_enhancer.fit([train_data, train_cb_data], train_target, validation_data=([val_data, val_cb_data], val_target), batch_size=16, epochs=epoch, callbacks=[cp_callback], shuffle=True)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 15s 391ms/step - loss: 4149.0425 - mse: 4149.0415 - accuracy: 0.4340 - val_loss: 1735.2095 - val_mse: 1735.2096 - val_accuracy: 0.5398
#
# Epoch 00001: val_loss improved from inf to 1735.20947, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 36/36 [==============================] - 14s 382ms/step - loss: 1952.4604 - mse: 1952.4607 - accuracy: 0.5183 - val_loss: 912.5213 - val_mse: 912.5215 - val_accuracy: 0.6191
#
# Epoch 00002: val_loss improved from 1735.20947 to 912.52130, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 3/100
# 36/36 [==============================] - 14s 382ms/step - loss: 1604.2026 - mse: 1604.2025 - accuracy: 0.5691 - val_loss: 959.9517 - val_mse: 959.9517 - val_accuracy: 0.5906
#
# Epoch 00003: val_loss did not improve from 912.52130
# Epoch 4/100
# 36/36 [==============================] - 14s 382ms/step - loss: 1320.9326 - mse: 1320.9326 - accuracy: 0.5977 - val_loss: 778.2007 - val_mse: 778.2007 - val_accuracy: 0.6717
#
# Epoch 00004: val_loss improved from 912.52130 to 778.20074, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 5/100
# 36/36 [==============================] - 14s 381ms/step - loss: 1225.0275 - mse: 1225.0275 - accuracy: 0.6101 - val_loss: 770.3181 - val_mse: 770.3181 - val_accuracy: 0.6875
#
# Epoch 00005: val_loss improved from 778.20074 to 770.31805, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 6/100
# 36/36 [==============================] - 14s 382ms/step - loss: 1170.1506 - mse: 1170.1505 - accuracy: 0.6221 - val_loss: 758.4160 - val_mse: 758.4160 - val_accuracy: 0.6503
#
# Epoch 00006: val_loss improved from 770.31805 to 758.41595, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 7/100
# 36/36 [==============================] - 14s 383ms/step - loss: 1106.7584 - mse: 1106.7587 - accuracy: 0.6384 - val_loss: 676.9738 - val_mse: 676.9739 - val_accuracy: 0.6829
#
# Epoch 00007: val_loss improved from 758.41595 to 676.97375, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 8/100
# 36/36 [==============================] - 14s 382ms/step - loss: 1119.4523 - mse: 1119.4521 - accuracy: 0.6409 - val_loss: 732.1126 - val_mse: 732.1126 - val_accuracy: 0.6122
#
# Epoch 00008: val_loss did not improve from 676.97375
# Epoch 9/100
# 36/36 [==============================] - 14s 383ms/step - loss: 1018.9167 - mse: 1018.9167 - accuracy: 0.6400 - val_loss: 800.4570 - val_mse: 800.4570 - val_accuracy: 0.7023
#
# Epoch 00009: val_loss did not improve from 676.97375
# Epoch 10/100
# 36/36 [==============================] - 14s 382ms/step - loss: 1039.2665 - mse: 1039.2665 - accuracy: 0.6322 - val_loss: 699.7438 - val_mse: 699.7438 - val_accuracy: 0.6965
#
# Epoch 00010: val_loss did not improve from 676.97375
# Epoch 11/100
# 36/36 [==============================] - 14s 382ms/step - loss: 978.6155 - mse: 978.6154 - accuracy: 0.6450 - val_loss: 720.6239 - val_mse: 720.6238 - val_accuracy: 0.6499
#
# Epoch 00011: val_loss did not improve from 676.97375
# Epoch 12/100
# 36/36 [==============================] - 14s 382ms/step - loss: 941.0159 - mse: 941.0162 - accuracy: 0.6526 - val_loss: 1165.8278 - val_mse: 1165.8278 - val_accuracy: 0.6914
#
# Epoch 00012: val_loss did not improve from 676.97375
# Epoch 13/100
# 36/36 [==============================] - 14s 382ms/step - loss: 912.1654 - mse: 912.1654 - accuracy: 0.6673 - val_loss: 588.6322 - val_mse: 588.6323 - val_accuracy: 0.7092
#
# Epoch 00013: val_loss improved from 676.97375 to 588.63220, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 14/100
# 36/36 [==============================] - 14s 381ms/step - loss: 909.9980 - mse: 909.9980 - accuracy: 0.6586 - val_loss: 600.4584 - val_mse: 600.4584 - val_accuracy: 0.7197
#
# Epoch 00014: val_loss did not improve from 588.63220
# Epoch 15/100
# 36/36 [==============================] - 14s 381ms/step - loss: 875.6417 - mse: 875.6419 - accuracy: 0.6707 - val_loss: 630.9546 - val_mse: 630.9546 - val_accuracy: 0.6638
#
# Epoch 00015: val_loss did not improve from 588.63220
# Epoch 16/100
# 36/36 [==============================] - 14s 381ms/step - loss: 906.4565 - mse: 906.4564 - accuracy: 0.6709 - val_loss: 641.7434 - val_mse: 641.7434 - val_accuracy: 0.7057
#
# Epoch 00016: val_loss did not improve from 588.63220
# Epoch 17/100
# 36/36 [==============================] - 14s 381ms/step - loss: 854.4908 - mse: 854.4910 - accuracy: 0.6797 - val_loss: 612.0574 - val_mse: 612.0574 - val_accuracy: 0.6969
#
# Epoch 00017: val_loss did not improve from 588.63220
# Epoch 18/100
# 36/36 [==============================] - 14s 382ms/step - loss: 848.2728 - mse: 848.2729 - accuracy: 0.6691 - val_loss: 674.7284 - val_mse: 674.7283 - val_accuracy: 0.7071
#
# Epoch 00018: val_loss did not improve from 588.63220
# Epoch 19/100
# 36/36 [==============================] - 14s 382ms/step - loss: 892.8001 - mse: 892.7998 - accuracy: 0.6636 - val_loss: 704.5278 - val_mse: 704.5278 - val_accuracy: 0.7008
#
# Epoch 00019: val_loss did not improve from 588.63220
# Epoch 20/100
# 36/36 [==============================] - 14s 382ms/step - loss: 839.7850 - mse: 839.7852 - accuracy: 0.6805 - val_loss: 564.3110 - val_mse: 564.3110 - val_accuracy: 0.7269
#
# Epoch 00020: val_loss improved from 588.63220 to 564.31097, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 21/100
# 36/36 [==============================] - 14s 382ms/step - loss: 803.4129 - mse: 803.4130 - accuracy: 0.6952 - val_loss: 613.9860 - val_mse: 613.9860 - val_accuracy: 0.7096
#
# Epoch 00021: val_loss did not improve from 564.31097
# Epoch 22/100
# 36/36 [==============================] - 14s 382ms/step - loss: 869.6826 - mse: 869.6825 - accuracy: 0.6906 - val_loss: 606.4820 - val_mse: 606.4819 - val_accuracy: 0.7385
#
# Epoch 00022: val_loss did not improve from 564.31097
# Epoch 23/100
# 36/36 [==============================] - 14s 382ms/step - loss: 801.4303 - mse: 801.4306 - accuracy: 0.6983 - val_loss: 574.0863 - val_mse: 574.0862 - val_accuracy: 0.7295
#
# Epoch 00023: val_loss did not improve from 564.31097
# Epoch 24/100
# 36/36 [==============================] - 14s 382ms/step - loss: 873.4938 - mse: 873.4938 - accuracy: 0.6967 - val_loss: 682.2180 - val_mse: 682.2180 - val_accuracy: 0.6567
#
# Epoch 00024: val_loss did not improve from 564.31097
# Epoch 25/100
# 36/36 [==============================] - 14s 381ms/step - loss: 797.6339 - mse: 797.6339 - accuracy: 0.6905 - val_loss: 768.5024 - val_mse: 768.5024 - val_accuracy: 0.6239
#
# Epoch 00025: val_loss did not improve from 564.31097
# Epoch 26/100
# 36/36 [==============================] - 14s 381ms/step - loss: 813.4364 - mse: 813.4365 - accuracy: 0.6871 - val_loss: 536.9399 - val_mse: 536.9400 - val_accuracy: 0.7358
#
# Epoch 00026: val_loss improved from 564.31097 to 536.93994, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 27/100
# 36/36 [==============================] - 14s 382ms/step - loss: 799.5338 - mse: 799.5339 - accuracy: 0.6970 - val_loss: 709.0892 - val_mse: 709.0893 - val_accuracy: 0.6741
#
# Epoch 00027: val_loss did not improve from 536.93994
# Epoch 28/100
# 36/36 [==============================] - 14s 381ms/step - loss: 807.5603 - mse: 807.5604 - accuracy: 0.7030 - val_loss: 543.0272 - val_mse: 543.0272 - val_accuracy: 0.7396
#
# Epoch 00028: val_loss did not improve from 536.93994
# Epoch 29/100
# 36/36 [==============================] - 14s 380ms/step - loss: 779.4674 - mse: 779.4675 - accuracy: 0.7025 - val_loss: 577.6482 - val_mse: 577.6482 - val_accuracy: 0.7148
#
# Epoch 00029: val_loss did not improve from 536.93994
# Epoch 30/100
# 36/36 [==============================] - 14s 381ms/step - loss: 819.1393 - mse: 819.1393 - accuracy: 0.7007 - val_loss: 655.9451 - val_mse: 655.9451 - val_accuracy: 0.7072
#
# Epoch 00030: val_loss did not improve from 536.93994
# Epoch 31/100
# 36/36 [==============================] - 14s 381ms/step - loss: 805.1877 - mse: 805.1878 - accuracy: 0.6999 - val_loss: 624.6990 - val_mse: 624.6990 - val_accuracy: 0.7394
#
# Epoch 00031: val_loss did not improve from 536.93994
# Epoch 32/100
# 36/36 [==============================] - 14s 382ms/step - loss: 795.3408 - mse: 795.3408 - accuracy: 0.6883 - val_loss: 598.9767 - val_mse: 598.9767 - val_accuracy: 0.7144
#
# Epoch 00032: val_loss did not improve from 536.93994
# Epoch 33/100
# 36/36 [==============================] - 14s 382ms/step - loss: 750.8391 - mse: 750.8392 - accuracy: 0.7146 - val_loss: 568.8711 - val_mse: 568.8711 - val_accuracy: 0.6527
#
# Epoch 00033: val_loss did not improve from 536.93994
# Epoch 34/100
# 36/36 [==============================] - 14s 381ms/step - loss: 755.5800 - mse: 755.5800 - accuracy: 0.6986 - val_loss: 590.7639 - val_mse: 590.7639 - val_accuracy: 0.7386
#
# Epoch 00034: val_loss did not improve from 536.93994
# Epoch 35/100
# 36/36 [==============================] - 14s 382ms/step - loss: 870.2362 - mse: 870.2362 - accuracy: 0.7103 - val_loss: 738.4583 - val_mse: 738.4583 - val_accuracy: 0.7265
#
# Epoch 00035: val_loss did not improve from 536.93994
# Epoch 36/100
# 36/36 [==============================] - 14s 382ms/step - loss: 1010.7502 - mse: 1010.7502 - accuracy: 0.6759 - val_loss: 618.5016 - val_mse: 618.5016 - val_accuracy: 0.7216
#
# Epoch 00036: val_loss did not improve from 536.93994
# Epoch 37/100
# 36/36 [==============================] - 14s 382ms/step - loss: 755.6664 - mse: 755.6664 - accuracy: 0.7012 - val_loss: 699.6805 - val_mse: 699.6805 - val_accuracy: 0.7139
#
# Epoch 00037: val_loss did not improve from 536.93994
# Epoch 38/100
# 36/36 [==============================] - 14s 381ms/step - loss: 820.4837 - mse: 820.4838 - accuracy: 0.6944 - val_loss: 601.5424 - val_mse: 601.5424 - val_accuracy: 0.7350
#
# Epoch 00038: val_loss did not improve from 536.93994
# Epoch 39/100
# 36/36 [==============================] - 14s 382ms/step - loss: 791.4259 - mse: 791.4262 - accuracy: 0.6939 - val_loss: 596.5004 - val_mse: 596.5004 - val_accuracy: 0.7416
#
# Epoch 00039: val_loss did not improve from 536.93994
# Epoch 40/100
# 36/36 [==============================] - 14s 382ms/step - loss: 807.7689 - mse: 807.7688 - accuracy: 0.7014 - val_loss: 757.8784 - val_mse: 757.8784 - val_accuracy: 0.7142
#
# Epoch 00040: val_loss did not improve from 536.93994
# Epoch 41/100
# 36/36 [==============================] - 14s 381ms/step - loss: 879.8585 - mse: 879.8585 - accuracy: 0.7032 - val_loss: 802.8951 - val_mse: 802.8951 - val_accuracy: 0.7077
#
# Epoch 00041: val_loss did not improve from 536.93994
# Epoch 42/100
# 36/36 [==============================] - 14s 380ms/step - loss: 824.0524 - mse: 824.0523 - accuracy: 0.7082 - val_loss: 575.1627 - val_mse: 575.1627 - val_accuracy: 0.6783
#
# Epoch 00042: val_loss did not improve from 536.93994
# Epoch 43/100
# 36/36 [==============================] - 14s 381ms/step - loss: 747.6749 - mse: 747.6749 - accuracy: 0.7201 - val_loss: 568.0082 - val_mse: 568.0082 - val_accuracy: 0.6825
#
# Epoch 00043: val_loss did not improve from 536.93994
# Epoch 44/100
# 36/36 [==============================] - 14s 382ms/step - loss: 727.7629 - mse: 727.7629 - accuracy: 0.7180 - val_loss: 536.6514 - val_mse: 536.6514 - val_accuracy: 0.7362
#
# Epoch 00044: val_loss improved from 536.93994 to 536.65137, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 45/100
# 36/36 [==============================] - 14s 381ms/step - loss: 756.0624 - mse: 756.0624 - accuracy: 0.7075 - val_loss: 550.1783 - val_mse: 550.1782 - val_accuracy: 0.7264
#
# Epoch 00045: val_loss did not improve from 536.65137
# Epoch 46/100
# 36/36 [==============================] - 14s 381ms/step - loss: 747.0413 - mse: 747.0412 - accuracy: 0.7152 - val_loss: 585.4788 - val_mse: 585.4788 - val_accuracy: 0.7486
#
# Epoch 00046: val_loss did not improve from 536.65137
# Epoch 47/100
# 36/36 [==============================] - 14s 382ms/step - loss: 792.2728 - mse: 792.2730 - accuracy: 0.6954 - val_loss: 547.5694 - val_mse: 547.5693 - val_accuracy: 0.7531
#
# Epoch 00047: val_loss did not improve from 536.65137
# Epoch 48/100
# 36/36 [==============================] - 14s 381ms/step - loss: 734.6148 - mse: 734.6150 - accuracy: 0.7084 - val_loss: 555.6878 - val_mse: 555.6879 - val_accuracy: 0.7240
#
# Epoch 00048: val_loss did not improve from 536.65137
# Epoch 49/100
# 36/36 [==============================] - 14s 382ms/step - loss: 783.3734 - mse: 783.3734 - accuracy: 0.7181 - val_loss: 563.4091 - val_mse: 563.4091 - val_accuracy: 0.7501
#
# Epoch 00049: val_loss did not improve from 536.65137
# Epoch 50/100
# 36/36 [==============================] - 14s 382ms/step - loss: 718.7982 - mse: 718.7982 - accuracy: 0.7324 - val_loss: 622.3869 - val_mse: 622.3869 - val_accuracy: 0.7148
#
# Epoch 00050: val_loss did not improve from 536.65137
# Epoch 51/100
# 36/36 [==============================] - 14s 382ms/step - loss: 740.9523 - mse: 740.9524 - accuracy: 0.7189 - val_loss: 527.9124 - val_mse: 527.9124 - val_accuracy: 0.7498
#
# Epoch 00051: val_loss improved from 536.65137 to 527.91241, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 52/100
# 36/36 [==============================] - 14s 380ms/step - loss: 735.0242 - mse: 735.0243 - accuracy: 0.7182 - val_loss: 532.2372 - val_mse: 532.2372 - val_accuracy: 0.7174
#
# Epoch 00052: val_loss did not improve from 527.91241
# Epoch 53/100
# 36/36 [==============================] - 14s 381ms/step - loss: 750.4003 - mse: 750.4004 - accuracy: 0.7120 - val_loss: 555.4031 - val_mse: 555.4032 - val_accuracy: 0.7443
#
# Epoch 00053: val_loss did not improve from 527.91241
# Epoch 54/100
# 36/36 [==============================] - 14s 381ms/step - loss: 695.3970 - mse: 695.3972 - accuracy: 0.7268 - val_loss: 554.1204 - val_mse: 554.1204 - val_accuracy: 0.7482
#
# Epoch 00054: val_loss did not improve from 527.91241
# Epoch 55/100
# 36/36 [==============================] - 14s 382ms/step - loss: 753.7382 - mse: 753.7381 - accuracy: 0.7221 - val_loss: 564.0175 - val_mse: 564.0175 - val_accuracy: 0.6931
#
# Epoch 00055: val_loss did not improve from 527.91241
# Epoch 56/100
# 36/36 [==============================] - 14s 381ms/step - loss: 721.5557 - mse: 721.5557 - accuracy: 0.7284 - val_loss: 548.9076 - val_mse: 548.9077 - val_accuracy: 0.6909
#
# Epoch 00056: val_loss did not improve from 527.91241
# Epoch 57/100
# 36/36 [==============================] - 14s 381ms/step - loss: 706.2764 - mse: 706.2764 - accuracy: 0.7091 - val_loss: 534.0135 - val_mse: 534.0134 - val_accuracy: 0.6991
#
# Epoch 00057: val_loss did not improve from 527.91241
# Epoch 58/100
# 36/36 [==============================] - 14s 381ms/step - loss: 707.5289 - mse: 707.5289 - accuracy: 0.7250 - val_loss: 607.9247 - val_mse: 607.9247 - val_accuracy: 0.7460
#
# Epoch 00058: val_loss did not improve from 527.91241
# Epoch 59/100
# 36/36 [==============================] - 14s 381ms/step - loss: 763.9581 - mse: 763.9578 - accuracy: 0.6994 - val_loss: 669.5208 - val_mse: 669.5208 - val_accuracy: 0.6874
#
# Epoch 00059: val_loss did not improve from 527.91241
# Epoch 60/100
# 36/36 [==============================] - 14s 381ms/step - loss: 778.4578 - mse: 778.4578 - accuracy: 0.6980 - val_loss: 562.4664 - val_mse: 562.4664 - val_accuracy: 0.7333
#
# Epoch 00060: val_loss did not improve from 527.91241
# Epoch 61/100
# 36/36 [==============================] - 14s 381ms/step - loss: 690.5488 - mse: 690.5487 - accuracy: 0.7346 - val_loss: 547.2386 - val_mse: 547.2386 - val_accuracy: 0.7497
#
# Epoch 00061: val_loss did not improve from 527.91241
# Epoch 62/100
# 36/36 [==============================] - 14s 381ms/step - loss: 690.7087 - mse: 690.7087 - accuracy: 0.7395 - val_loss: 517.5943 - val_mse: 517.5942 - val_accuracy: 0.7433
#
# Epoch 00062: val_loss improved from 527.91241 to 517.59430, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 63/100
# 36/36 [==============================] - 14s 381ms/step - loss: 751.9219 - mse: 751.9218 - accuracy: 0.7343 - val_loss: 607.5137 - val_mse: 607.5136 - val_accuracy: 0.7487
#
# Epoch 00063: val_loss did not improve from 517.59430
# Epoch 64/100
# 36/36 [==============================] - 14s 381ms/step - loss: 730.5637 - mse: 730.5638 - accuracy: 0.7381 - val_loss: 684.2144 - val_mse: 684.2144 - val_accuracy: 0.7395
#
# Epoch 00064: val_loss did not improve from 517.59430
# Epoch 65/100
# 36/36 [==============================] - 14s 381ms/step - loss: 762.3742 - mse: 762.3743 - accuracy: 0.7148 - val_loss: 568.5366 - val_mse: 568.5364 - val_accuracy: 0.6766
#
# Epoch 00065: val_loss did not improve from 517.59430
# Epoch 66/100
# 36/36 [==============================] - 14s 381ms/step - loss: 707.6923 - mse: 707.6923 - accuracy: 0.7281 - val_loss: 567.1389 - val_mse: 567.1389 - val_accuracy: 0.7426
#
# Epoch 00066: val_loss did not improve from 517.59430
# Epoch 67/100
# 36/36 [==============================] - 14s 382ms/step - loss: 686.6104 - mse: 686.6103 - accuracy: 0.7342 - val_loss: 513.6026 - val_mse: 513.6026 - val_accuracy: 0.7595
#
# Epoch 00067: val_loss improved from 517.59430 to 513.60260, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 68/100
# 36/36 [==============================] - 14s 381ms/step - loss: 683.8564 - mse: 683.8565 - accuracy: 0.7262 - val_loss: 522.9794 - val_mse: 522.9795 - val_accuracy: 0.7346
#
# Epoch 00068: val_loss did not improve from 513.60260
# Epoch 69/100
# 36/36 [==============================] - 14s 382ms/step - loss: 714.5068 - mse: 714.5070 - accuracy: 0.7233 - val_loss: 575.3822 - val_mse: 575.3822 - val_accuracy: 0.7172
#
# Epoch 00069: val_loss did not improve from 513.60260
# Epoch 70/100
# 36/36 [==============================] - 14s 381ms/step - loss: 689.5644 - mse: 689.5644 - accuracy: 0.7326 - val_loss: 612.2432 - val_mse: 612.2433 - val_accuracy: 0.6993
#
# Epoch 00070: val_loss did not improve from 513.60260
# Epoch 71/100
# 36/36 [==============================] - 14s 382ms/step - loss: 675.0460 - mse: 675.0460 - accuracy: 0.7330 - val_loss: 554.0394 - val_mse: 554.0394 - val_accuracy: 0.7332
#
# Epoch 00071: val_loss did not improve from 513.60260
# Epoch 72/100
# 36/36 [==============================] - 14s 381ms/step - loss: 696.9978 - mse: 696.9979 - accuracy: 0.7267 - val_loss: 520.7215 - val_mse: 520.7215 - val_accuracy: 0.7545
#
# Epoch 00072: val_loss did not improve from 513.60260
# Epoch 73/100
# 36/36 [==============================] - 14s 381ms/step - loss: 702.1051 - mse: 702.1050 - accuracy: 0.7335 - val_loss: 583.4491 - val_mse: 583.4490 - val_accuracy: 0.7351
#
# Epoch 00073: val_loss did not improve from 513.60260
# Epoch 74/100
# 36/36 [==============================] - 14s 381ms/step - loss: 706.0351 - mse: 706.0351 - accuracy: 0.7334 - val_loss: 559.8409 - val_mse: 559.8409 - val_accuracy: 0.7547
#
# Epoch 00074: val_loss did not improve from 513.60260
# Epoch 75/100
# 36/36 [==============================] - 14s 380ms/step - loss: 678.1880 - mse: 678.1878 - accuracy: 0.7306 - val_loss: 527.3555 - val_mse: 527.3555 - val_accuracy: 0.7420
#
# Epoch 00075: val_loss did not improve from 513.60260
# Epoch 76/100
# 36/36 [==============================] - 14s 382ms/step - loss: 708.5407 - mse: 708.5408 - accuracy: 0.7358 - val_loss: 532.9439 - val_mse: 532.9439 - val_accuracy: 0.7559
#
# Epoch 00076: val_loss did not improve from 513.60260
# Epoch 77/100
# 36/36 [==============================] - 14s 381ms/step - loss: 698.8109 - mse: 698.8110 - accuracy: 0.7400 - val_loss: 636.3284 - val_mse: 636.3284 - val_accuracy: 0.7609
#
# Epoch 00077: val_loss did not improve from 513.60260
# Epoch 78/100
# 36/36 [==============================] - 14s 380ms/step - loss: 684.4334 - mse: 684.4334 - accuracy: 0.7313 - val_loss: 521.2061 - val_mse: 521.2061 - val_accuracy: 0.7347
#
# Epoch 00078: val_loss did not improve from 513.60260
# Epoch 79/100
# 36/36 [==============================] - 14s 380ms/step - loss: 683.5414 - mse: 683.5414 - accuracy: 0.7354 - val_loss: 551.5439 - val_mse: 551.5439 - val_accuracy: 0.7517
#
# Epoch 00079: val_loss did not improve from 513.60260
# Epoch 80/100
# 36/36 [==============================] - 14s 379ms/step - loss: 721.9553 - mse: 721.9553 - accuracy: 0.7384 - val_loss: 797.6248 - val_mse: 797.6248 - val_accuracy: 0.6950
#
# Epoch 00080: val_loss did not improve from 513.60260
# Epoch 81/100
# 36/36 [==============================] - 14s 379ms/step - loss: 781.8982 - mse: 781.8983 - accuracy: 0.7051 - val_loss: 554.5642 - val_mse: 554.5642 - val_accuracy: 0.7277
#
# Epoch 00081: val_loss did not improve from 513.60260
# Epoch 82/100
# 36/36 [==============================] - 14s 380ms/step - loss: 678.1418 - mse: 678.1419 - accuracy: 0.7364 - val_loss: 569.1749 - val_mse: 569.1749 - val_accuracy: 0.7203
#
# Epoch 00082: val_loss did not improve from 513.60260
# Epoch 83/100
# 36/36 [==============================] - 14s 380ms/step - loss: 702.1171 - mse: 702.1170 - accuracy: 0.7359 - val_loss: 599.7098 - val_mse: 599.7098 - val_accuracy: 0.7452
#
# Epoch 00083: val_loss did not improve from 513.60260
# Epoch 84/100
# 36/36 [==============================] - 14s 380ms/step - loss: 705.7946 - mse: 705.7945 - accuracy: 0.7351 - val_loss: 525.5928 - val_mse: 525.5928 - val_accuracy: 0.7456
#
# Epoch 00084: val_loss did not improve from 513.60260
# Epoch 85/100
# 36/36 [==============================] - 14s 379ms/step - loss: 705.9681 - mse: 705.9680 - accuracy: 0.7279 - val_loss: 541.8619 - val_mse: 541.8619 - val_accuracy: 0.7427
#
# Epoch 00085: val_loss did not improve from 513.60260
# Epoch 86/100
# 36/36 [==============================] - 14s 380ms/step - loss: 678.7235 - mse: 678.7236 - accuracy: 0.7443 - val_loss: 505.2042 - val_mse: 505.2042 - val_accuracy: 0.7529
#
# Epoch 00086: val_loss improved from 513.60260 to 505.20416, saving model to /content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5
# Epoch 87/100
# 36/36 [==============================] - 14s 380ms/step - loss: 691.8542 - mse: 691.8541 - accuracy: 0.7350 - val_loss: 600.3320 - val_mse: 600.3319 - val_accuracy: 0.7024
#
# Epoch 00087: val_loss did not improve from 505.20416
# Epoch 88/100
# 36/36 [==============================] - 14s 380ms/step - loss: 685.3653 - mse: 685.3653 - accuracy: 0.7340 - val_loss: 532.5153 - val_mse: 532.5153 - val_accuracy: 0.7030
#
# Epoch 00088: val_loss did not improve from 505.20416
# Epoch 89/100
# 36/36 [==============================] - 14s 379ms/step - loss: 685.8806 - mse: 685.8806 - accuracy: 0.7339 - val_loss: 589.5174 - val_mse: 589.5173 - val_accuracy: 0.7138
#
# Epoch 00089: val_loss did not improve from 505.20416
# Epoch 90/100
# 36/36 [==============================] - 14s 380ms/step - loss: 779.7164 - mse: 779.7166 - accuracy: 0.7266 - val_loss: 604.5859 - val_mse: 604.5859 - val_accuracy: 0.7376
#
# Epoch 00090: val_loss did not improve from 505.20416
# Epoch 91/100
# 36/36 [==============================] - 14s 380ms/step - loss: 783.5109 - mse: 783.5110 - accuracy: 0.7060 - val_loss: 597.3330 - val_mse: 597.3330 - val_accuracy: 0.6794
#
# Epoch 00091: val_loss did not improve from 505.20416
# Epoch 92/100
# 36/36 [==============================] - 14s 380ms/step - loss: 666.3625 - mse: 666.3626 - accuracy: 0.7260 - val_loss: 554.4197 - val_mse: 554.4197 - val_accuracy: 0.7449
#
# Epoch 00092: val_loss did not improve from 505.20416
# Epoch 93/100
# 36/36 [==============================] - 14s 379ms/step - loss: 738.6438 - mse: 738.6438 - accuracy: 0.7313 - val_loss: 591.8383 - val_mse: 591.8383 - val_accuracy: 0.7106
#
# Epoch 00093: val_loss did not improve from 505.20416
# Epoch 94/100
# 36/36 [==============================] - 14s 380ms/step - loss: 685.3519 - mse: 685.3520 - accuracy: 0.7286 - val_loss: 512.2440 - val_mse: 512.2440 - val_accuracy: 0.7466
#
# Epoch 00094: val_loss did not improve from 505.20416
# Epoch 95/100
# 36/36 [==============================] - 14s 380ms/step - loss: 728.2894 - mse: 728.2894 - accuracy: 0.7374 - val_loss: 653.6655 - val_mse: 653.6655 - val_accuracy: 0.7331
#
# Epoch 00095: val_loss did not improve from 505.20416
# Epoch 96/100
# 36/36 [==============================] - 14s 379ms/step - loss: 667.0728 - mse: 667.0728 - accuracy: 0.7367 - val_loss: 515.9019 - val_mse: 515.9019 - val_accuracy: 0.7399
#
# Epoch 00096: val_loss did not improve from 505.20416
# Epoch 97/100
# 36/36 [==============================] - 14s 380ms/step - loss: 661.2196 - mse: 661.2197 - accuracy: 0.7459 - val_loss: 570.8024 - val_mse: 570.8025 - val_accuracy: 0.7475
#
# Epoch 00097: val_loss did not improve from 505.20416
# Epoch 98/100
# 36/36 [==============================] - 14s 379ms/step - loss: 684.1351 - mse: 684.1351 - accuracy: 0.7274 - val_loss: 542.7681 - val_mse: 542.7682 - val_accuracy: 0.7489
#
# Epoch 00098: val_loss did not improve from 505.20416
# Epoch 99/100
# 36/36 [==============================] - 14s 380ms/step - loss: 697.2191 - mse: 697.2192 - accuracy: 0.7417 - val_loss: 726.1434 - val_mse: 726.1434 - val_accuracy: 0.7007
#
# Epoch 00099: val_loss did not improve from 505.20416
# Epoch 100/100
# 36/36 [==============================] - 14s 380ms/step - loss: 709.2899 - mse: 709.2900 - accuracy: 0.7283 - val_loss: 510.7951 - val_mse: 510.7951 - val_accuracy: 0.7445
#
# Epoch 00100: val_loss did not improve from 505.20416

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'accuracy', 'val_loss', 'val_mse', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='validation')
plt.legend()
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
###################################################################################################### TESTING PART ####################################################################################################

# %%
###### How to load and use weights from a checkpoint #########

im_h = 224
im_w = 224

# initiate keras tensor input_sample, input_cb_sample, and output_
input_sample = Input(shape=(im_h, im_w, 3))
input_cb_sample = Input(shape=(im_h, im_w, 3))
output_ = cnn_model(input_sample, input_cb_sample)

# create the model in function way by specfying input and output
model_enhancer_test = Model(inputs=[input_sample, input_cb_sample], outputs=output_)

# load weights
model_enhancer_test.load_weights("/content/drive/MyDrive/UnderwaterImageEnhancement/checkpoints/model5/weights_best.hdf5")

# Configures the model for training with loss function and optimizer
model_enhancer_test.compile(loss='mse', optimizer='adam', metrics=['mse', 'accuracy'])

# %%
############################################################# Evaluate the model in testing part

d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/raw'
cb_d_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/cb_raw'
t_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'

data = []
cb_data = []
target = []

im_h = 224
im_w = 224
for imagePath in os.listdir(d_path):

    # get full the path of the raw(real), cb_raw(color balancing real) and reference(target) images
    data_path = os.path.join(d_path, imagePath)
    cb_data_path = os.path.join(cb_d_path, imagePath)
    target_path = os.path.join(t_path, imagePath)
    
    #read the images
    img = cv2.imread(data_path)
    cb_img = cv2.imread(cb_data_path)
    target_img = cv2.imread(target_path)

    #resize the images 
    img = cv2.resize(img, (im_h, im_w))
    cb_img = cv2.resize(cb_img, (im_h, im_w))
    target_img = cv2.resize(target_img, (im_h, im_w))
        
    # put the images into array list
    data.append(img)
    cb_data.append(cb_img)
    target.append(target_img)


# convert arrays into numpy arrays
test_data = np.array(data)
test_cb_data = np.array(cb_data)
test_target = np.array(target)

print(test_data.shape, test_cb_data.shape, test_target.shape)

# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5/'

# save the numpy arrays
np.save('test_data', test_data)
np.save('test_cb_data', test_cb_data)
np.save('test_target', test_target)
# Out:
# (178, 224, 224, 3) (178, 224, 224, 3) (178, 224, 224, 3)
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5

# %%
# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5/'

# load the numpy arrays
test_data = np.load('test_data.npy')
test_cb_data = np.load('test_cb_data.npy')
test_target = np.load('test_target.npy')

print(test_data.shape, test_cb_data.shape, test_target.shape)


# estimate accuracy and the MSE on test dataset using loaded weights
scores = model_enhancer_test.evaluate([test_data, test_cb_data ], test_target, verbose=0)

#print("%s: %.2f%%" % (model_enhancer_test.metrics_names[2], scores[2]*100))
# Out:
# /content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5
# (178, 224, 224, 3) (178, 224, 224, 3) (178, 224, 224, 3)

# %%
# Testing Accuracy
print("%s: %.2f%%" % (model_enhancer_test.metrics_names[2], scores[2]*100))
# Out:
# accuracy: 74.17%

# %%
# Testing Loss - MSE for test data set
print(scores[1])
print('MSE for testing set: ', format(scores[1], ".4f"))
# Out:
# 489.65020751953125
# MSE for testing set:  489.6502

# %%
# PSNR for test data set

from math import log10, sqrt

def PSNR():
 mse = scores[1]
 #print(mse)
 if(mse == 0):
  return 100
 max_pixel = 255.0
 psnr = 20 * log10(max_pixel / sqrt(mse))
 return psnr 

value = PSNR()
print(value)

print('PSNR for testing set: ', format(value, ".4f"), "dB")
# Out:
# 21.23194417966646
# PSNR for testing set:  21.2319 dB

# %%
############################################################## predict the data using loaded weights

import numpy as np
from PIL import Image
import cv2
import os
from matplotlib import pyplot as plt


test_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/raw/'
cb_test_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/cb_raw'
destination = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model5-output/'

im_h = 224
im_w = 224
for test_img_name in os.listdir(test_path):

    #read the raw images
    test_img = cv2.imread(os.path.join(test_path, test_img_name))
    cb_test_img = cv2.imread(os.path.join(cb_test_path, test_img_name))
   
    #resize the images into 112 x 112
    test_img = cv2.resize(test_img, (im_h, im_w))
    cb_test_img = cv2.resize(cb_test_img, (im_h, im_w))
    
    # reshape the image (112, 112, 3) into (1, 112, 112, 3)
    test_img = test_img.reshape(1,im_h, im_w,3)
    cb_test_img = cb_test_img.reshape(1,im_h, im_w,3)


    # use model to do prediction
    #result = model_enhancer.predict([test_img, cb_test_img])
    result = model_enhancer_test.predict([test_img, cb_test_img])
    

    
    #
    result = result.squeeze()
    
    test_img = test_img.squeeze()
    
    test_img[:,:,:] = result[:,:,:]
    #plt.imshow(test_img)
    cv2.imwrite(os.path.join(destination, test_img_name), test_img)

# %%
"""

import numpy as np
import cv2
import os

from sklearn.metrics import mean_squared_error

target_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'
predicted_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model5-output/'

target_data = []
predict_data = []


im_h = 224
im_w = 224
for image_name in os.listdir(target_path):

    #read the raw images
    target_img = cv2.imread(os.path.join(target_path, image_name))
    predicted_img = cv2.imread(os.path.join(predicted_path, image_name))
    

    #resize the images into 112 x 112
    target_img = cv2.resize(target_img, (im_h, im_w))
    predicted_img = cv2.resize(predicted_img, (im_h, im_w))
        
    # put the images into array list
    target_data.append(target_img)
    predict_data.append(predicted_img)


# convert arrays into numpy arrays
target_data = np.array(target_data)
predict_data = np.array(predict_data)

print(target_data.shape, predict_data.shape)


# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5/'

# save the numpy arrays
np.save('target_data', target_data)
np.save('predict_data', predict_data)



"""

# %%
"""

# %cd '/content/drive/MyDrive/UnderwaterImageEnhancement/models/npfile-model5/'

# load the numpy arrays
target_data = np.load('target_data.npy')
predict_data = np.load('predict_data.npy')

print(target_data.shape, predict_data.shape)

"""

# %%
"""

###### FULL-REFERENCE IMAGE QUALITY ASSESSMENT IN TERMS OF MSE, PSNR, AND SSIM #######

import numpy as np
  
# Mean Squared Error
MSE = np.square(np.subtract(target_data,predict_data)).mean()
print("MSE for test data :",format(MSE, ".4f"))


"""

# %%
"""

mse = (np.square(target_data - predict_data)).mean(axis=None)

print("MSE for test data :",format(mse, ".4f"))

"""

# %%
"""

# PSNR 

from math import log10, sqrt

def PSNR(target_data, predict_data):
 mse = np.mean((target_data - predict_data) ** 2)
 #print(mse)
 if(mse == 0):
  return 100
 max_pixel = 255.0
 psnr = 20 * log10(max_pixel / sqrt(mse))
 return psnr 


value = PSNR(target_data, predict_data)
print("\nPeak Signal-to-Noise Ratio (PSNR) value is", format(value, ".4f"), "dB")


"""

# %%
"""

#SSIM

from skimage.metrics import structural_similarity as ssim

ssim_value = ssim(target_data, predict_data, multichannel=True)
print("SSIM:", format(ssim_value, ".4f"))

"""

# %%
"""

from skimage.measure import compare_ssim

(score, diff) = compare_ssim(target_data, predict_data, full=True, multichannel=True)
diff = (diff * 255).astype("uint8")
print("SSIM:", format(score, ".4f"))


"""

# %%
###### FULL-REFERENCE IMAGE QUALITY ASSESSMENT IN TERMS OF MSE, PSNR, AND SSIM #######

import numpy as np
import cv2
import os

from skimage.metrics import mean_squared_error
from skimage.metrics import peak_signal_noise_ratio
from skimage.metrics import structural_similarity 


target_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'
predicted_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/model5-output/'



im_h = 224
im_w = 224

sumMSE = 0;
sumPSNR = 0;
sumSSIM = 0;
count = 0;


for image_name in os.listdir(target_path):

    #read the raw images
    target_img = cv2.imread(os.path.join(target_path, image_name))
    predicted_img = cv2.imread(os.path.join(predicted_path, image_name))
    

    #resize the images into 224 x 224
    target_img = cv2.resize(target_img, (im_h, im_w))
    predicted_img = cv2.resize(predicted_img, (im_h, im_w))


    #calculate the MSE, PSNR, and SSIM 
    MSE = mean_squared_error(target_img, predicted_img)
    PSNR = peak_signal_noise_ratio(target_img, predicted_img)
    SSIM = structural_similarity(target_img, predicted_img, multichannel=True)
    #print(SSIM)

    sumMSE = sumMSE + MSE
    sumPSNR = sumPSNR + PSNR
    sumSSIM = sumSSIM + SSIM
    count = count + 1
    
    # print('SSIM: ', SSIM)
    # print('MSE: ', MSE)
    # print('PSNR: ', PSNR)


# print('sumMSE: ',sumMSE)
# print('sumPSNR: ', sumPSNR)
# print('sumSSIM: ', sumSSIM)
# print('count: ', count)


# Get the Average value 
mse_value = sumMSE/count
psnr_value = sumPSNR/count
ssim_value = sumSSIM/count


print("MSE for testing data :", format(mse_value, ".4f"))
print("PSNR for testing data :", format(psnr_value, ".4f"),"dB")
print("SSIM for testing data :", format(ssim_value, ".4f"))
# Out:
# MSE for testing data : 695.7952
# PSNR for testing data : 20.7302 dB
# SSIM for testing data : 0.8640

# %%
### Resized the reference Image

import numpy as np
import cv2
import os

target_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference'
resized_target_path = '/content/drive/MyDrive/UnderwaterImageEnhancement/dataset/test-set/reference_resized'

for image_name in os.listdir(target_path):

    #read the raw images
    target_img = cv2.imread(os.path.join(target_path, image_name))
    

    #resize the images into 224 x 224
    target_img = cv2.resize(target_img, (im_h, im_w))
  
    cv2.imwrite(os.path.join(resized_target_path, image_name), test_img)
